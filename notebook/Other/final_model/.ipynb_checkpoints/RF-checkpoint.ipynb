# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.utils import class_weight
from sklearn.metrics import classification_report, roc_auc_score, roc_curve
import matplotlib.pyplot as plt
from imblearn.under_sampling import RandomUnderSampler
from sklearn.ensemble import RandomForestClassifier

# 载入数据
data = pd.read_csv("E:\竞赛\服创赛-A08\data\特征集\output_file_2.csv")

# %%
# 在结尾处获取要删除的特征列表
# data = data.drop(columns=list(features_to_remove))
# data.head()

# %%
# 获取重要性最低的特征
# least_important_features = feature_importances_df.tail(1)

# # 删除这些特征
# data = data.drop(columns=least_important_features['Feature Name'])

# %%
# 分离特征和目标变量
X = data.drop('RES', axis=1)
y = data['RES']

# 划分数据集
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# %%
# 计算类别权重
weights = class_weight.compute_class_weight('balanced', classes=np.unique(y_train), y=y_train)
weight_dict = {i : weights[i] for i in range(len(weights))}

# 应用Random Under Sampler
rus = RandomUnderSampler(random_state=42,sampling_strategy = {0: 2000, 1: 556})
X_train_rus, y_train_rus = rus.fit_resample(X_train, y_train)


X_train_rus.shape
# Out:
# (2556, 116)

# %%
# 创建随机森林分类器实例
rf = RandomForestClassifier(
    n_estimators=228,       # 树的数量
    # criterion='gini',       # 用于分裂的质量度量，也可以是 'entropy'
    max_depth=None,         # 树的最大深度
    # min_samples_split=2,    # 分裂内部节点所需的最少样本数
    # min_samples_leaf=1,     # 在叶节点处需要的最少样本数
    # min_weight_fraction_leaf=0.0, # 在所有叶子节点处的权重总和中的最小加权分数
    # max_features='sqrt',    # 寻找最佳分割时考虑的特征数量
    # max_leaf_nodes=None,    # 以最佳优先方式增长树时的最大叶子节点数
    # min_impurity_decrease=0.0,    # 如果节点分裂导致不纯度减少大于或等于此值，则分裂节点
    # bootstrap=True,         # 是否在构建树时使用bootstrap样本
    oob_score=False,        # 是否使用袋外样本来估计泛化精度
    n_jobs=-1,              # 拟合和预测时并行运行的作业数
    random_state=42,        # 控制组件的随机性
    verbose=0,              # 控制拟合和预测的冗长程度
    warm_start=True,       # 设置为True时，重用上一个调用的解决方案以适应并在集合中添加更多的估计器
    # class_weight=weight_dict,      # 类别的权重
    # ccp_alpha=0.0,          # 用于最小成本-复杂性剪枝的复杂性参数
    # max_samples=None        # 如果 bootstrap 为 True，从 X 抽取的样本数
)


# 训练模型
rf.fit(X_train_rus, y_train_rus)

# 预测
train_preds = rf.predict(X_train_rus)
test_preds = rf.predict(X_test)
train_proba = rf.predict_proba(X_train_rus)[:, 1]
test_proba = rf.predict_proba(X_test)[:, 1]

# %%
# 性能评估
train_classification_report = classification_report(y_train_rus, train_preds)
test_classification_report = classification_report(y_test, test_preds)
train_roc_auc = roc_auc_score(y_train_rus, train_proba)
test_roc_auc = roc_auc_score(y_test, test_proba)

# 绘制ROC曲线
fpr_train, tpr_train, _ = roc_curve(y_train_rus, train_proba)
fpr_test, tpr_test, _ = roc_curve(y_test, test_proba)

plt.figure(figsize=(10, 6))
plt.plot(fpr_train, tpr_train, label=f'Training ROC curve (area = {train_roc_auc:.2f})')
plt.plot(fpr_test, tpr_test, label=f'Test ROC curve (area = {test_roc_auc:.2f})')
plt.plot([0, 1], [0, 1], 'k--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve with LightGBM')
plt.legend()
plt.show()

# %%
from sklearn.metrics import classification_report

# Calculate the classification reports
train_classification_report = classification_report(y_train_rus, train_preds)
test_classification_report = classification_report(y_test, test_preds)

# Print the classification reports
print("Training Set Classification Report:\n", train_classification_report)
print("\nTest Set Classification Report:\n", test_classification_report)
# Out:
# Training Set Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      2000
#            1       1.00      1.00      1.00       556
#
#     accuracy                           1.00      2556
#    macro avg       1.00      1.00      1.00      2556
# weighted avg       1.00      1.00      1.00      2556
#
#
# Test Set Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.98      0.96      0.97      3802
#            1       0.46      0.61      0.53       198
#
#     accuracy                           0.95      4000
#    macro avg       0.72      0.79      0.75      4000
# weighted avg       0.95      0.95      0.95      4000

# %%
# 设置阈值
threshold = 0.6

# 以概率形式获取预测结果
y_probs = rf.predict_proba(X_test)[:, 1] # 获取正类的概率

# 应用阈值
y_pred_thresh = np.where(y_probs > threshold, 1, 0)

# 生成分类报告
classification_report_06 = classification_report(y_test, y_pred_thresh)

print(classification_report_06)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.98      3802
#            1       0.57      0.47      0.52       198
#
#     accuracy                           0.96      4000
#    macro avg       0.77      0.73      0.75      4000
# weighted avg       0.95      0.96      0.95      4000

# %%
auc_score = roc_auc_score(y_test, rf.predict_proba(X_test)[:, 1])

print("Test AUC Score:", auc_score)
X_train_rus.shape
# Out:
# Test AUC Score: 0.9259646703755069
# (2556, 116)

# %%
# import joblib

# # 保存模型和特征
# model_features = {
#     'model': rf,
#     'features': X_train.columns.tolist()
# }
# joblib.dump(model_features, 'E:\竞赛\服创赛-A08\\model\\rf\\rf_model_6_0.91737.pkl')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
rc = {'font.sans-serif': 'SimHei',
      'axes.unicode_minus': False}
sns.set(context='notebook', style='ticks', rc=rc)


from sklearn.feature_selection import mutual_info_classif
# %matplotlib inline
pd.set_option("display.max_columns",100)
pd.set_option('display.max_rows',100)

from pylab import mpl 
plt.rcParams['font.sans-serif'] = ['Microsoft YaHei']  # 设置中文字体
plt.rcParams['axes.unicode_minus'] = False  # 为了显示负号正常

import warnings
warnings.filterwarnings("ignore")

# %%
# 获取特征重要性
feature_importance = rf.feature_importances_

# 转换为Pandas DataFrame
feature_names = X_train.columns
feature_importances_df = pd.DataFrame({'Feature Name': feature_names, 'Importance': feature_importance})

# 对特征重要性进行排序
feature_importances_df = feature_importances_df.sort_values(by='Importance', ascending=False)

# 可视化特征重要性
plt.figure(figsize=(20, 20))
plt.title('Feature Importances')
plt.barh(feature_importances_df['Feature Name'], feature_importances_df['Importance'])
plt.gca().invert_yaxis()
plt.show()

# %%
feature_importances_df
# Out:
#      Feature Name  Importance
# 10      月统筹金额_MAX    0.054127
# 103        月统筹金额差    0.047575
# 111     月统筹金额差_调整    0.041454
# 64     本次审批金额_SUM    0.037431
# 28        ALL_SUM    0.030796
# ..            ...         ...
# 95      床位费自费金额占比    0.000000
# 93      手术费自费金额占比    0.000000
# 25       住院天数_SUM    0.000000
# 23    交易时间YYYY_NN    0.000000
# 58   最高限额以上金额_SUM    0.000000
#
# [116 rows x 2 columns]

# %%
high_corr_pairs = []
correlation_matrix = data.corr()
for col in correlation_matrix.columns:
    for row in correlation_matrix.index:
        if (correlation_matrix.loc[row, col] > 0.9) and (col != row):
            # Check if the pair is already added
            if not {(row, col), (col, row)}.intersection(set(high_corr_pairs)):
                high_corr_pairs.append((row, col))

high_corr_pairs
# Out:
# [('交易时间YYYYMM_NN', '就诊的月数'),
#  ('月就诊天数_AVG', '月就诊天数_MAX'),
#  ('就诊次数_SUM', '月就诊天数_MAX'),
#  ('月就诊次数_MAX', '月就诊天数_MAX'),
#  ('月就诊次数_AVG', '月就诊天数_MAX'),
#  ('交易时间DD_NN', '月就诊天数_MAX'),
#  ('就诊次数_SUM', '月就诊天数_AVG'),
#  ('月就诊次数_MAX', '月就诊天数_AVG'),
#  ('月就诊次数_AVG', '月就诊天数_AVG'),
#  ('交易时间DD_NN', '月就诊天数_AVG'),
#  ('月就诊医院数_AVG', '月就诊医院数_MAX'),
#  ('医院编码_NN', '月就诊医院数_MAX'),
#  ('月就诊次数_MAX', '就诊次数_SUM'),
#  ('月就诊次数_AVG', '就诊次数_SUM'),
#  ('顺序号_NN', '就诊次数_SUM'),
#  ('交易时间DD_NN', '就诊次数_SUM'),
#  ('月就诊次数_AVG', '月就诊次数_MAX'),
#  ('交易时间DD_NN', '月就诊次数_AVG'),
#  ('统筹支付金额_SUM', '月统筹金额_AVG'),
#  ('ALL_SUM', '月统筹金额_AVG'),
#  ('基本统筹基金支付金额_SUM', '月统筹金额_AVG'),
#  ('本次审批金额_SUM', '月统筹金额_AVG'),
#  ('月药品金额_AVG', '月药品金额_MAX'),
#  ('药品费发生金额_SUM', '月药品金额_MAX'),
#  ('药品费申报金额_SUM', '月药品金额_MAX'),
#  ('药品费发生金额_SUM', '月药品金额_AVG'),
#  ('药品费申报金额_SUM', '月药品金额_AVG'),
#  ('统筹支付金额_SUM', '医院_统筹金_MAX'),
#  ('可用账户报销金额_SUM', '个人账户金额_SUM'),
#  ('非账户支付金额_SUM', '个人账户金额_SUM'),
#  ('ALL_SUM', '统筹支付金额_SUM'),
#  ('起付标准以上自负比例金额_SUM', '统筹支付金额_SUM'),
#  ('基本统筹基金支付金额_SUM', '统筹支付金额_SUM'),
#  ('本次审批金额_SUM', '统筹支付金额_SUM'),
#  ('本次审批金额_SUM', 'ALL_SUM'),
#  ('非账户支付金额_SUM', '可用账户报销金额_SUM'),
#  ('药品费申报金额_SUM', '药品费发生金额_SUM'),
#  ('检查费申报金额_SUM', '检查费发生金额_SUM'),
#  ('治疗费申报金额_SUM', '治疗费发生金额_SUM'),
#  ('手术费申报金额_SUM', '手术费发生金额_SUM'),
#  ('床位费申报金额_SUM', '床位费发生金额_SUM'),
#  ('一次性医用材料申报金额_SUM', '医用材料发生金额_SUM'),
#  ('基本统筹基金支付金额_SUM', '起付标准以上自负比例金额_SUM'),
#  ('医疗救助医院申请_SUM', '医疗救助个人按比例负担金额_SUM'),
#  ('补助审批金额_SUM', '城乡救助补助金额_SUM'),
#  ('民政救助补助_SUM', '城乡救助补助金额_SUM'),
#  ('民政救助补助_SUM', '补助审批金额_SUM'),
#  ('药品费自费金额占比', '个人支付的药品占比'),
#  ('检查费自费金额占比', '个人支付检查费用占比'),
#  ('治疗费自费金额占比', '个人支付治疗费用占比'),
#  ('医疗救助个人按比例负担金额_SUM_是异常值', '医疗救助个人按比例负担金额_SUM_大于平均值'),
#  ('月就诊天数差_调整', '月就诊天数差'),
#  ('月就诊医院数差_调整', '月就诊医院数差'),
#  ('月统筹金额差_调整', '月统筹金额差'),
#  ('月药品金额差_调整', '月药品金额差'),
#  ('医院_就诊天数差_调整', '医院_就诊天数差'),
#  ('医院_统筹金差_调整', '医院_统筹金差'),
#  ('医院_药品差_调整', '医院_药品差')]

# %%
# 初始化要删除的特征列表
# 特征a与特征b高度相关，但是特征a的特征重要性大于b，那么就删除特征b
features_to_remove = set()

for feature1, feature2 in high_corr_pairs:
    # 获取两个特征的重要性
    importance_feature1 = feature_importances_df[feature_importances_df['Feature Name'] == feature1]['Importance'].values[0]
    importance_feature2 = feature_importances_df[feature_importances_df['Feature Name'] == feature2]['Importance'].values[0]

    # 比较重要性并添加较低的一个到删除列表
    if importance_feature1 > importance_feature2:
        features_to_remove.add(feature2)
    else:
        features_to_remove.add(feature1)

# 输出要删除的特征列表
features_to_remove
# Out:
# {'ALL_SUM',
#  '一次性医用材料申报金额_SUM',
#  '个人账户金额_SUM',
#  '交易时间DD_NN',
#  '医疗救助个人按比例负担金额_SUM',
#  '医疗救助个人按比例负担金额_SUM_是异常值',
#  '医院_就诊天数差',
#  '医院_统筹金_MAX',
#  '医院_统筹金差',
#  '医院_药品差',
#  '可用账户报销金额_SUM',
#  '基本统筹基金支付金额_SUM',
#  '就诊次数_SUM',
#  '就诊的月数',
#  '床位费申报金额_SUM',
#  '手术费发生金额_SUM',
#  '月就诊医院数_MAX',
#  '月就诊医院数差_调整',
#  '月就诊天数_AVG',
#  '月就诊天数差',
#  '月就诊次数_AVG',
#  '月就诊次数_MAX',
#  '月统筹金额_AVG',
#  '月统筹金额差_调整',
#  '月药品金额_AVG',
#  '月药品金额差_调整',
#  '检查费申报金额_SUM',
#  '检查费自费金额占比',
#  '民政救助补助_SUM',
#  '治疗费申报金额_SUM',
#  '治疗费自费金额占比',
#  '统筹支付金额_SUM',
#  '药品费发生金额_SUM',
#  '药品费申报金额_SUM',
#  '药品费自费金额占比',
#  '补助审批金额_SUM',
#  '起付标准以上自负比例金额_SUM'}

# %%
# Initialize the loop
for iteration in range(5):  # Adjust the number of iterations as needed
    # Train the RandomForestClassifier
    rf = RandomForestClassifier(
        n_estimators=228,       # Adjust parameters as needed
        max_depth=None
        # ... other parameters
    )
    rf.fit(X_train_rus, y_train_rus)
    
    # Evaluate the model
    # ... (evaluation code from Cell 7)

    # Save the model
    # ... (model saving code from Cell 11)

    # Calculate feature importance and remove the two least important features
    feature_importance = rf.feature_importances_
    feature_names = X_train.columns
    feature_importances_df = pd.DataFrame({'Feature Name': feature_names, 'Importance': feature_importance})
    feature_importances_df = feature_importances_df.sort_values(by='Importance', ascending=True)
    # Removing the two least important features
    features_to_remove = feature_importances_df.head(2)['Feature Name'].tolist()
    X_train.drop(columns=features_to_remove, inplace=True)
    X_test.drop(columns=features_to_remove, inplace=True)

    # Output progress
    print(f"Iteration {iteration+1}: Model trained and saved. Removed features: {features_to_remove}")

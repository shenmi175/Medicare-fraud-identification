# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from ipywidgets import interactive
import plotly.express as px
from ipywidgets import interact, Dropdown, Select
import ipywidgets as widgets
import plotly.graph_objects as go
import seaborn as sns
rc = {'font.sans-serif': 'SimHei',
      'axes.unicode_minus': False}
sns.set(context='notebook', style='ticks', rc=rc)


from sklearn.feature_selection import mutual_info_classif
# %matplotlib inline
pd.set_option("display.max_columns",100)
pd.set_option('display.max_rows',100)

from pylab import mpl 
plt.rcParams['font.sans-serif'] = ['Microsoft YaHei']  # 设置中文字体
plt.rcParams['axes.unicode_minus'] = False  # 为了显示负号正常

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # 数据总览

# %%
# 读取CSV文件
file_path = "E:\竞赛\服创赛-A08\data\process_data.csv"
df = pd.read_csv(file_path)
data = df

# 指定需要统计的列名
column_name = 'RES'

# 统计指定列中0和1的数量
count_0 = df[column_name].eq(0).sum()
count_1 = df[column_name].eq(1).sum()

# 打印结果
print(f"在列 '{column_name}' 中，0 的数量为: {count_0}")
print(f"在列 '{column_name}' 中，1 的数量为: {count_1}")
# Out:
# 在列 'RES' 中，0 的数量为: 15207
# 在列 'RES' 中，1 的数量为: 793

# %%
# 删除“个人编码”特征列
df.drop('个人编码', axis=1, inplace=True)

# 统计特征的数量
num_features = len(df.columns)

# 打印特征数量结果
print(f"样本中的特征数量为: {num_features}")
# Out:
# 样本中的特征数量为: 81

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16000 entries, 0 to 15999
# Data columns (total 81 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   一天去两家医院的天数         16000 non-null  int64
#  1   就诊的月数              16000 non-null  int64
#  2   月就诊天数_MAX          16000 non-null  int64
#  3   月就诊天数_AVG          16000 non-null  float64
#  4   月就诊医院数_MAX         16000 non-null  int64
#  5   月就诊医院数_AVG         16000 non-null  float64
#  6   就诊次数_SUM           16000 non-null  int64
#  7   月就诊次数_MAX          16000 non-null  int64
#  8   月就诊次数_AVG          16000 non-null  float64
#  9   月统筹金额_MAX          16000 non-null  float64
#  10  月统筹金额_AVG          16000 non-null  float64
#  11  月药品金额_MAX          16000 non-null  float64
#  12  月药品金额_AVG          16000 non-null  float64
#  13  医院_就诊天数_MAX        16000 non-null  int64
#  14  医院_就诊天数_AVG        16000 non-null  float64
#  15  医院_统筹金_MAX         16000 non-null  float64
#  16  医院_统筹金_AVG         16000 non-null  float64
#  17  医院_药品_MAX          16000 non-null  float64
#  18  医院_药品_AVG          16000 non-null  float64
#  19  医院编码_NN            16000 non-null  int64
#  20  顺序号_NN             16000 non-null  int64
#  21  交易时间DD_NN          16000 non-null  int64
#  22  交易时间YYYY_NN        16000 non-null  int64
#  23  交易时间YYYYMM_NN      16000 non-null  int64
#  24  住院天数_SUM           16000 non-null  int64
#  25  个人账户金额_SUM         16000 non-null  float64
#  26  统筹支付金额_SUM         16000 non-null  float64
#  27  ALL_SUM            16000 non-null  float64
#  28  可用账户报销金额_SUM       16000 non-null  float64
#  29  药品费发生金额_SUM        16000 non-null  float64
#  30  药品费自费金额_SUM        16000 non-null  float64
#  31  药品费申报金额_SUM        16000 non-null  float64
#  32  贵重药品发生金额_SUM       16000 non-null  float64
#  33  中成药费发生金额_SUM       16000 non-null  float64
#  34  中草药费发生金额_SUM       16000 non-null  float64
#  35  检查费发生金额_SUM        16000 non-null  float64
#  36  检查费自费金额_SUM        16000 non-null  float64
#  37  检查费申报金额_SUM        16000 non-null  float64
#  38  贵重检查费金额_SUM        16000 non-null  int64
#  39  治疗费发生金额_SUM        16000 non-null  float64
#  40  治疗费自费金额_SUM        16000 non-null  float64
#  41  治疗费申报金额_SUM        16000 non-null  float64
#  42  手术费发生金额_SUM        16000 non-null  int64
#  43  手术费自费金额_SUM        16000 non-null  int64
#  44  手术费申报金额_SUM        16000 non-null  float64
#  45  床位费发生金额_SUM        16000 non-null  float64
#  46  床位费申报金额_SUM        16000 non-null  float64
#  47  医用材料发生金额_SUM       16000 non-null  float64
#  48  高价材料发生金额_SUM       16000 non-null  float64
#  49  医用材料费自费金额_SUM      16000 non-null  float64
#  50  成分输血申报金额_SUM       16000 non-null  int64
#  51  其它发生金额_SUM         16000 non-null  float64
#  52  其它申报金额_SUM         16000 non-null  int64
#  53  一次性医用材料申报金额_SUM    16000 non-null  float64
#  54  起付线标准金额_MAX        16000 non-null  float64
#  55  起付标准以上自负比例金额_SUM   16000 non-null  float64
#  56  医疗救助个人按比例负担金额_SUM  16000 non-null  float64
#  57  最高限额以上金额_SUM       16000 non-null  float64
#  58  基本统筹基金支付金额_SUM     16000 non-null  float64
#  59  公务员医疗补助基金支付金额_SUM  16000 non-null  float64
#  60  城乡救助补助金额_SUM       16000 non-null  float64
#  61  基本个人账户支付_SUM       16000 non-null  float64
#  62  非账户支付金额_SUM        16000 non-null  float64
#  63  本次审批金额_SUM         16000 non-null  float64
#  64  补助审批金额_SUM         16000 non-null  float64
#  65  医疗救助医院申请_SUM       16000 non-null  float64
#  66  残疾军人补助_SUM         16000 non-null  float64
#  67  民政救助补助_SUM         16000 non-null  float64
#  68  城乡优抚补助_SUM         16000 non-null  float64
#  69  出院诊断病种名称_NN        16000 non-null  int64
#  70  出院诊断LENTH_MAX      16000 non-null  float64
#  71  药品在总金额中的占比         16000 non-null  float64
#  72  个人支付的药品占比          16000 non-null  float64
#  73  检查总费用在总金额占比        16000 non-null  float64
#  74  个人支付检查费用占比         16000 non-null  float64
#  75  治疗费用在总金额占比         16000 non-null  float64
#  76  个人支付治疗费用占比         16000 non-null  float64
#  77  BZ_民政救助            16000 non-null  int64
#  78  BZ_城乡优抚            16000 non-null  int64
#  79  是否挂号               16000 non-null  int64
#  80  RES                16000 non-null  int64
# dtypes: float64(58), int64(23)
# memory usage: 9.9 MB

# %%
# 使用describe方法进行描述性统计
description = df.describe(include='all')

# 打印描述性统计结果
print("描述性统计结果：")
print(description)
# Out:
# 描述性统计结果：
#          一天去两家医院的天数         就诊的月数     月就诊天数_MAX     月就诊天数_AVG    月就诊医院数_MAX  \
# count  16000.000000  16000.000000  16000.000000  16000.000000  16000.000000
# mean       1.883875      5.817812      7.824438      5.854813      2.099000
# std        5.227365      0.702069      4.193234      3.377273      0.947038
# min        0.000000      1.000000      1.000000      1.000000      1.000000
# 25%        0.000000      6.000000      5.000000      3.500000      1.000000
# 50%        0.000000      6.000000      7.000000      5.166667      2.000000
# 75%        0.000000      6.000000     10.000000      7.333333      3.000000
# max      108.000000      7.000000     31.000000     30.000000      8.000000
#
#          月就诊医院数_AVG      就诊次数_SUM     月就诊次数_MAX     月就诊次数_AVG     月统筹金额_MAX  \
# count  16000.000000  16000.000000  16000.000000  16000.000000  16000.000000
# mean       1.735954     36.818438      8.419250      6.264291   3943.185445
# std        0.724497     23.656539      5.199283      3.940291   2936.217833
# min        1.000000      1.000000      1.000000      1.000000      0.000000
# 25%        1.000000     22.000000      5.000000      3.666667   2420.145000
# 50%        1.666667     32.000000      7.000000      5.333333   3125.405000
# 75%        2.000000     46.000000     10.000000      7.833333   4464.017500
# max        7.000000    307.000000     75.000000     51.166667  44590.330000
#
#           月统筹金额_AVG     月药品金额_MAX     月药品金额_AVG   医院_就诊天数_MAX   医院_就诊天数_AVG  \
# count  16000.000000  16000.000000  16000.000000  16000.000000  16000.000000
# mean    2783.040791   3631.380422   2602.861947     26.638500     19.079701
# std     1857.794225   2682.941527   1776.066792     17.587198     14.173003
# min        0.000000      0.000000      0.000000      1.000000      1.000000
# 25%     1793.384583   2351.600000   1751.854583     14.000000     10.666667
# 50%     2255.458333   3001.875000   2184.220833     23.000000     15.000000
# 75%     3135.721667   4119.525000   2948.170000     33.000000     23.000000
# max    37403.050000  77841.700000  38656.056670    180.000000    172.000000
#
#           医院_统筹金_MAX     医院_统筹金_AVG      医院_药品_MAX      医院_药品_AVG  \
# count   16000.000000   16000.000000   16000.000000   16000.000000
# mean    12602.672037    9056.441440   11696.530186    8257.661369
# std      9507.692019    8318.767632    8555.770743    6948.782110
# min         0.000000       0.000000       0.000000       0.000000
# 25%      7624.852500    4730.801250    7449.155000    4583.521250
# 50%     10279.710000    6562.982500   10104.070000    6364.521667
# 75%     13993.330000   10622.245000   13465.987500   10196.982500
# max    100726.770000  100726.770000  203167.880000  151598.250000
#
#             医院编码_NN        顺序号_NN     交易时间DD_NN  交易时间YYYY_NN  交易时间YYYYMM_NN  \
# count  16000.000000  16000.000000  16000.000000      16000.0   16000.000000
# mean       2.197500     91.459750     34.419375          1.0       5.817812
# std        1.048302     64.978792     20.400236          0.0       0.702069
# min        1.000000      1.000000      1.000000          1.0       1.000000
# 25%        1.000000     54.000000     21.000000          1.0       6.000000
# 50%        2.000000     78.000000     30.000000          1.0       6.000000
# 75%        3.000000    110.000000     43.000000          1.0       6.000000
# max        9.000000   1415.000000    180.000000          1.0       7.000000
#
#        住院天数_SUM    个人账户金额_SUM     统筹支付金额_SUM        ALL_SUM  可用账户报销金额_SUM  \
# count   16000.0  16000.000000   16000.000000   16000.000000  16000.000000
# mean        0.0   2318.743704   16248.157033   18581.903839   2200.475267
# std         0.0   2427.725593   10696.643485   13507.065808   2369.065418
# min         0.0      1.450000       0.000000       4.000000      0.000000
# 25%         0.0   1208.200000   10555.920000   11901.582500   1142.730000
# 50%         0.0   1629.650000   13303.175000   14868.435000   1530.875000
# 75%         0.0   2445.572500   18474.095000   20599.815000   2295.292500
# max         0.0  45518.610000  125861.490000  240320.340000  45518.580000
#
#          药品费发生金额_SUM   药品费自费金额_SUM    药品费申报金额_SUM   贵重药品发生金额_SUM  \
# count   16000.000000  16000.000000   16000.000000   16000.000000
# mean    15275.711085     80.603902   15023.718634    2709.672334
# std     10536.443992    215.586310   10240.500007    6256.166307
# min         0.000000      0.000000       0.000000       0.000000
# 25%     10313.175000      0.040000   10190.357500       0.000000
# 50%     12876.790000      8.250000   12740.265000    1094.870000
# 75%     17441.580000     67.642500   17189.670000    2893.660000
# max    231936.340000  11165.130000  224594.610000  189729.700000
#
#         中成药费发生金额_SUM  中草药费发生金额_SUM   检查费发生金额_SUM   检查费自费金额_SUM   检查费申报金额_SUM  \
# count   16000.000000  16000.000000  16000.000000  16000.000000  16000.000000
# mean     3401.571010   2389.157068    598.063251     10.267001    580.508156
# std      3818.560983   3333.948935    908.926822     88.452731    855.831610
# min         0.000000      0.000000      0.000000      0.000000      0.000000
# 25%      1440.892500      0.000000     18.000000      0.000000     18.000000
# 50%      2703.155000    537.515000    273.000000      0.000000    271.000000
# 75%      4280.675000   4180.015000    783.000000      0.000000    771.000000
# max    115738.150000  34412.120000  13941.000000   3864.000000  10685.400000
#
#         贵重检查费金额_SUM   治疗费发生金额_SUM   治疗费自费金额_SUM   治疗费申报金额_SUM   手术费发生金额_SUM  \
# count  16000.000000  16000.000000  16000.000000  16000.000000  16000.000000
# mean      60.580062   2385.897406      8.733015   2348.499072      7.891188
# std      308.040347   7070.959992     94.206063   6940.260261    162.875183
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.000000    216.000000      0.000000    213.000000      0.000000
# 50%        0.000000    401.000000      0.000000    394.000000      0.000000
# 75%        0.000000    807.000000      0.000000    791.625000      0.000000
# max     7670.000000  52120.000000   7750.000000  51087.800000   7975.000000
#
#         手术费自费金额_SUM   手术费申报金额_SUM   床位费发生金额_SUM   床位费申报金额_SUM  医用材料发生金额_SUM  \
# count  16000.000000  16000.000000  16000.000000  16000.000000  16000.000000
# mean       0.090000      7.800469      5.195688      5.150125    301.377911
# std        5.830707    162.763860     30.771234     30.710988    520.176901
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.000000      0.000000      0.000000      6.890000
# 50%        0.000000      0.000000      0.000000      0.000000    177.940000
# 75%        0.000000      0.000000      0.000000      0.000000    464.800000
# max      600.000000   7975.000000    795.000000    795.000000  31303.100000
#
#        高价材料发生金额_SUM  医用材料费自费金额_SUM  成分输血申报金额_SUM    其它发生金额_SUM    其它申报金额_SUM  \
# count  16000.000000   16000.000000  16000.000000  16000.000000  16000.000000
# mean      17.197364      10.763950     10.078250      7.767312      0.048625
# std      427.518396     100.977949    443.899162     29.998053      3.263327
# min        0.000000       0.000000      0.000000      0.000000      0.000000
# 25%        0.000000       0.000000      0.000000      0.000000      0.000000
# 50%        0.000000       0.000000      0.000000      0.000000      0.000000
# 75%        0.000000       0.000000      0.000000      6.000000      0.000000
# max    31270.800000    4154.100000  39718.000000    750.000000    375.000000
#
#        一次性医用材料申报金额_SUM   起付线标准金额_MAX  起付标准以上自负比例金额_SUM  医疗救助个人按比例负担金额_SUM  \
# count     16000.000000  16000.000000      16000.000000       16000.000000
# mean        263.894079      7.405927       2315.785588         101.078898
# std         474.467387    111.156022       2253.697641        1140.931780
# min           0.000000      0.000000          0.000000           0.000000
# 25%           1.000000      0.000000       1223.840000           0.000000
# 50%         123.100000      0.000000       1594.130000           0.000000
# 75%         439.365000      0.000000       2346.115000           0.000000
# max       28257.540000   3638.480000      23643.030000       39457.270000
#
#        最高限额以上金额_SUM  基本统筹基金支付金额_SUM  公务员医疗补助基金支付金额_SUM  城乡救助补助金额_SUM  \
# count  16000.000000    16000.000000       16000.000000  16000.000000
# mean       0.079136    15440.051715          51.805779    377.007672
# std       10.010032     9016.969096         514.786578   1670.137464
# min        0.000000        0.000000           0.000000      0.000000
# 25%        0.000000    10407.455000           0.000000      0.000000
# 50%        0.000000    13035.855000           0.000000      0.000000
# 75%        0.000000    17851.357500           0.000000      0.000000
# max     1266.180000   117786.270000       18465.360000  43123.200000
#
#        基本个人账户支付_SUM   非账户支付金额_SUM     本次审批金额_SUM    补助审批金额_SUM   医疗救助医院申请_SUM  \
# count  16000.000000  16000.000000   16000.000000  16000.000000   16000.000000
# mean     126.748913   2191.994791   18236.173922    572.439964     404.379674
# std      204.646380   2415.539590   13107.096667   2295.805737    4563.731157
# min        0.000000      0.000000       3.000000      0.000000       0.000000
# 25%        0.000000   1090.832500   11742.340000      0.000000       0.000000
# 50%      104.575000   1506.365000   14676.875000      0.000000       0.000000
# 75%      165.217500   2310.055000   20275.970000      0.000000       0.000000
# max     8297.080000  45345.100000  232978.610000  53903.790000  157830.320000
#
#          残疾军人补助_SUM    民政救助补助_SUM    城乡优抚补助_SUM   出院诊断病种名称_NN  出院诊断LENTH_MAX  \
# count  16000.000000  16000.000000  16000.000000  16000.000000   16000.000000
# mean       3.618437    374.437024      1.236406      5.343438      25.454687
# std      212.888960   1660.898502     78.017209      2.889941      12.802942
# min        0.000000      0.000000      0.000000      0.000000       0.000000
# 25%        0.000000      0.000000      0.000000      3.000000      17.000000
# 50%        0.000000      0.000000      0.000000      5.000000      25.000000
# 75%        0.000000      0.000000      0.000000      7.000000      34.000000
# max    16965.630000  43123.200000   8913.440000     39.000000      86.000000
#
#          药品在总金额中的占比     个人支付的药品占比   检查总费用在总金额占比    个人支付检查费用占比    治疗费用在总金额占比  \
# count  16000.000000  16000.000000  16000.000000  16000.000000  16000.000000
# mean       0.854763      0.005500      0.039006      0.005560      0.081316
# std        0.168843      0.013990      0.064466      0.032765      0.155653
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.845445      0.000003      0.001170      0.000000      0.015839
# 50%        0.907803      0.000569      0.016690      0.000000      0.027925
# 75%        0.946247      0.004818      0.049281      0.000000      0.051846
# max        1.000000      0.689375      0.962401      1.000000      1.000000
#
#          个人支付治疗费用占比       BZ_民政救助       BZ_城乡优抚          是否挂号           RES
# count  16000.000000  16000.000000  16000.000000  16000.000000  16000.000000
# mean       0.010609      0.143125      0.000562      0.253250      0.049563
# std        0.056906      0.350211      0.023711      0.434886      0.217046
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.000000      0.000000      0.000000      0.000000
# 50%        0.000000      0.000000      0.000000      0.000000      0.000000
# 75%        0.000000      0.000000      0.000000      1.000000      0.000000
# max        0.883652      1.000000      1.000000      1.000000      1.000000

# %%
# 对欺诈与非欺诈分别进行描述性统计分析
desc_stats_fraud = df[df['RES'] == 1].describe()
desc_stats_nonfraud = df[df['RES'] == 0].describe()

print("欺诈:\n",desc_stats_fraud)
print("______________")
print("非欺诈：\n",desc_stats_nonfraud)
# Out:
# 欺诈:
#         一天去两家医院的天数       就诊的月数   月就诊天数_MAX   月就诊天数_AVG  月就诊医院数_MAX  月就诊医院数_AVG  \
# count  793.000000  793.000000  793.000000  793.000000  793.000000  793.000000
# mean     7.609079    5.568726   12.895334    9.620405    2.578815    2.095451
# std     14.773407    1.090885    7.462390    6.211821    1.285763    1.025574
# min      0.000000    1.000000    1.000000    1.000000    1.000000    1.000000
# 25%      0.000000    6.000000    6.000000    3.833333    2.000000    1.166667
# 50%      0.000000    6.000000   13.000000    8.833333    2.000000    2.000000
# 75%      9.000000    6.000000   18.000000   14.166667    3.000000    2.666667
# max    108.000000    7.000000   31.000000   28.833333    8.000000    7.000000
#
#          就诊次数_SUM   月就诊次数_MAX   月就诊次数_AVG     月统筹金额_MAX     月统筹金额_AVG  \
# count  793.000000  793.000000  793.000000    793.000000    793.000000
# mean    62.923077   15.756620   11.206735   8598.079168   5260.668820
# std     51.109265   11.946959    8.458459   6543.892393   3889.796012
# min      5.000000    1.000000    1.000000      0.000000      0.000000
# 25%     22.000000    7.000000    4.000000   3022.290000   1802.345000
# 50%     47.000000   14.000000    9.833333   7278.150000   4312.701667
# 75%     91.000000   21.000000   15.666667  12238.820000   7870.966667
# max    307.000000   75.000000   51.166667  39630.410000  20976.915000
#
#           月药品金额_MAX     月药品金额_AVG  医院_就诊天数_MAX  医院_就诊天数_AVG    医院_统筹金_MAX  \
# count    793.000000    793.000000   793.000000   793.000000    793.000000
# mean    7578.997415   4973.927511    41.776797    26.134033  21765.554376
# std     7148.800203   4571.028376    32.422703    21.977790  19402.967329
# min      156.480000     53.845000     3.000000     2.000000      0.000000
# 25%     2443.550000   1621.426667    15.000000    10.000000   6886.260000
# 50%     5239.500000   3365.375000    29.000000    19.285714  13553.710000
# 75%    10089.860000   6939.626000    69.000000    34.666667  33687.870000
# max    49344.890000  38656.056670   170.000000   139.000000  99035.930000
#
#          医院_统筹金_AVG      医院_药品_MAX      医院_药品_AVG     医院编码_NN       顺序号_NN  \
# count    793.000000     793.000000     793.000000  793.000000   793.000000
# mean   13766.276643   19507.855902   12012.374006    2.721311   174.780580
# std    14875.930999   20385.543925   14019.520408    1.403193   164.925442
# min        0.000000     323.070000     323.070000    1.000000    11.000000
# 25%     4109.424000    6478.640000    3669.834000    2.000000    52.000000
# 50%     8543.387500   11571.900000    7513.360000    3.000000   121.000000
# 75%    16973.630000   25495.250000   15021.310000    3.000000   255.000000
# max    83145.440000  203167.880000  127472.760000    9.000000  1415.000000
#
#         交易时间DD_NN  交易时间YYYY_NN  交易时间YYYYMM_NN  住院天数_SUM    个人账户金额_SUM  \
# count  793.000000        793.0     793.000000     793.0    793.000000
# mean    54.108449          1.0       5.568726       0.0   5408.392673
# std     38.204505          0.0       1.090885       0.0   5822.745435
# min      5.000000          1.0       1.000000       0.0     54.440000
# 25%     21.000000          1.0       6.000000       0.0   1174.960000
# 50%     43.000000          1.0       6.000000       0.0   3058.950000
# 75%     83.000000          1.0       6.000000       0.0   7729.580000
# max    173.000000          1.0       7.000000       0.0  31842.580000
#
#           统筹支付金额_SUM        ALL_SUM  可用账户报销金额_SUM    药品费发生金额_SUM  \
# count     793.000000     793.000000    793.000000     793.000000
# mean    29552.955675   38592.590794   5152.099092   28152.080832
# std     23563.219670   34038.478896   5698.231039   27651.504557
# min         0.000000     989.070000      0.000000     323.070000
# 25%      9546.310000   10812.620000   1112.380000    8630.050000
# 50%     20557.540000   24159.010000   2887.390000   17417.180000
# 75%     45770.280000   60586.380000   7067.120000   40422.470000
# max    125861.490000  240320.340000  30373.000000  231936.340000
#
#         药品费自费金额_SUM    药品费申报金额_SUM   贵重药品发生金额_SUM   中成药费发生金额_SUM  \
# count    793.000000     793.000000     793.000000     793.000000
# mean     156.969559   27485.925309    7003.568852    5992.199937
# std      485.417630   26893.658173   13480.226921    9144.596537
# min        0.000000     323.070000       0.000000       0.000000
# 25%        0.840000    8523.830000     156.410000    1149.340000
# 50%       24.520000   17003.300000    2504.320000    2982.210000
# 75%      162.430000   39439.320000    7608.480000    6604.940000
# max    11165.130000  224594.610000  174479.310000  115738.150000
#
#        中草药费发生金额_SUM   检查费发生金额_SUM  检查费自费金额_SUM   检查费申报金额_SUM  贵重检查费金额_SUM  \
# count    793.000000    793.000000   793.000000    793.000000   793.000000
# mean    1715.072812    783.632799    28.130404    744.067844    93.709962
# std     3593.165261   1228.390343   180.505022   1128.868452   340.619099
# min        0.000000      0.000000     0.000000      0.000000     0.000000
# 25%        0.000000     30.000000     0.000000     30.000000     0.000000
# 50%        0.000000    321.000000     0.000000    321.000000     0.000000
# 75%     1808.560000   1035.000000     0.000000   1022.000000     0.000000
# max    29254.560000  10847.000000  2880.000000  10670.000000  3672.000000
#
#         治疗费发生金额_SUM  治疗费自费金额_SUM   治疗费申报金额_SUM  手术费发生金额_SUM  手术费自费金额_SUM  \
# count    793.000000   793.000000    793.000000   793.000000   793.000000
# mean    9288.269042    16.279193   9113.486318    12.388398     0.416141
# std    15075.066520   190.867380  14783.228714   198.235055    10.678537
# min        1.500000     0.000000      1.500000     0.000000     0.000000
# 25%      273.500000     0.000000    270.500000     0.000000     0.000000
# 50%     1038.500000     0.000000   1023.000000     0.000000     0.000000
# 75%     9432.000000     0.000000   9432.000000     0.000000     0.000000
# max    52017.000000  5040.000000  51087.800000  4675.000000   300.000000
#
#        手术费申报金额_SUM  床位费发生金额_SUM  床位费申报金额_SUM  医用材料发生金额_SUM  高价材料发生金额_SUM  \
# count   793.000000   793.000000   793.000000    793.000000    793.000000
# mean     11.972257     7.861917     7.783733    339.938323     73.672320
# std     197.888224    35.269509    35.172827    800.043326    646.035083
# min       0.000000     0.000000     0.000000      0.000000      0.000000
# 25%       0.000000     0.000000     0.000000      1.000000      0.000000
# 50%       0.000000     0.000000     0.000000     84.000000      0.000000
# 75%       0.000000     0.000000     0.000000    392.000000      0.000000
# max    4675.000000   468.000000   468.000000  11425.550000  11371.200000
#
#        医用材料费自费金额_SUM  成分输血申报金额_SUM  其它发生金额_SUM  其它申报金额_SUM  一次性医用材料申报金额_SUM  \
# count     793.000000    793.000000  793.000000  793.000000       793.000000
# mean       46.170555      8.544767    8.419483    0.179067       272.911538
# std       324.084727    240.622815   22.834037    3.849861       696.460089
# min         0.000000      0.000000    0.000000    0.000000         0.000000
# 25%         0.000000      0.000000    0.000000    0.000000         0.000000
# 50%         0.000000      0.000000    0.000000    0.000000        47.500000
# 75%         1.800000      0.000000    4.800000    0.000000       301.640000
# max      4154.100000   6776.000000  222.400000  100.000000     10318.960000
#
#        起付线标准金额_MAX  起付标准以上自负比例金额_SUM  医疗救助个人按比例负担金额_SUM  最高限额以上金额_SUM  \
# count   793.000000        793.000000         793.000000         793.0
# mean      9.438625       5313.580290        1427.891740           0.0
# std      99.624622       4881.821147        4328.291926           0.0
# min       0.000000          0.000000           0.000000           0.0
# 25%       0.000000       1134.030000           0.000000           0.0
# 50%       0.000000       2971.140000           0.000000           0.0
# 75%       0.000000       9074.180000           0.000000           0.0
# max    1300.000000      23643.030000       39457.270000           0.0
#
#        基本统筹基金支付金额_SUM  公务员医疗补助基金支付金额_SUM  城乡救助补助金额_SUM  基本个人账户支付_SUM  \
# count      793.000000         793.000000    793.000000    793.000000
# mean     25200.731803         184.139887   2080.701047    124.697667
# std      18837.456782        1458.460147   5225.230124    188.990750
# min          0.000000           0.000000      0.000000      0.000000
# 25%       9205.050000           0.000000      0.000000      0.000000
# 50%      19257.450000           0.000000      0.000000     92.200000
# 75%      39258.900000           0.000000      0.000000    156.000000
# max     117786.270000       18465.360000  43123.200000   1397.800000
#
#         非账户支付金额_SUM     本次审批金额_SUM    补助审批金额_SUM   医疗救助医院申请_SUM    残疾军人补助_SUM  \
# count    793.000000     793.000000    793.000000     793.000000    793.000000
# mean    5283.695006   37575.993367   2835.566898    5712.858348     15.357554
# std     5809.258133   33085.516524   6791.292829   17312.787043    432.472636
# min        4.220000     989.070000      0.000000       0.000000      0.000000
# 25%     1070.450000   10593.960000      0.000000       0.000000      0.000000
# 50%     2894.840000   23326.600000      0.000000       0.000000      0.000000
# 75%     7513.520000   59438.340000      0.000000       0.000000      0.000000
# max    31842.580000  232978.610000  53903.790000  157830.320000  12178.540000
#
#          民政救助补助_SUM   城乡优抚补助_SUM  出院诊断病种名称_NN  出院诊断LENTH_MAX  药品在总金额中的占比  \
# count    793.000000   793.000000   793.000000     793.000000  793.000000
# mean    2070.500820     1.524565     7.346784      26.467844    0.780945
# std     5206.447957    42.932139     5.188813      13.247519    0.245794
# min        0.000000     0.000000     0.000000       0.000000    0.037708
# 25%        0.000000     0.000000     4.000000      19.000000    0.614069
# 50%        0.000000     0.000000     6.000000      26.000000    0.911091
# 75%        0.000000     0.000000    10.000000      35.000000    0.959876
# max    43123.200000  1208.980000    39.000000      70.000000    0.998028
#
#         个人支付的药品占比  检查总费用在总金额占比  个人支付检查费用占比  治疗费用在总金额占比  个人支付治疗费用占比  \
# count  793.000000   793.000000  793.000000  793.000000  793.000000
# mean     0.006044     0.027615    0.011646    0.176635    0.005767
# std      0.012761     0.049236    0.046141    0.240611    0.036698
# min      0.000000     0.000000    0.000000    0.000114    0.000000
# 25%      0.000071     0.001723    0.000000    0.017949    0.000000
# 50%      0.000941     0.012232    0.000000    0.034043    0.000000
# 75%      0.006906     0.029402    0.000000    0.331760    0.000000
# max      0.198166     0.478019    0.501901    0.914335    0.523286
#
#           BZ_民政救助     BZ_城乡优抚        是否挂号    RES
# count  793.000000  793.000000  793.000000  793.0
# mean     0.244641    0.001261    0.230769    1.0
# std      0.430145    0.035511    0.421591    0.0
# min      0.000000    0.000000    0.000000    1.0
# 25%      0.000000    0.000000    0.000000    1.0
# 50%      0.000000    0.000000    0.000000    1.0
# 75%      0.000000    0.000000    0.000000    1.0
# max      1.000000    1.000000    1.000000    1.0
# ______________
# 非欺诈：
#           一天去两家医院的天数         就诊的月数     月就诊天数_MAX     月就诊天数_AVG    月就诊医院数_MAX  \
# count  15207.000000  15207.000000  15207.000000  15207.000000  15207.000000
# mean       1.585323      5.830802      7.560005      5.658449      2.073979
# std        3.947680      0.673216      3.766803      3.035290      0.919192
# min        0.000000      1.000000      1.000000      1.000000      1.000000
# 25%        0.000000      6.000000      5.000000      3.500000      1.000000
# 50%        0.000000      6.000000      7.000000      5.000000      2.000000
# 75%        0.000000      6.000000      9.000000      7.166667      3.000000
# max       54.000000      7.000000     31.000000     30.000000      7.000000
#
#          月就诊医院数_AVG      就诊次数_SUM     月就诊次数_MAX     月就诊次数_AVG     月统筹金额_MAX  \
# count  15207.000000  15207.000000  15207.000000  15207.000000  15207.000000
# mean       1.717207     35.457158      8.036628      6.006557   3700.446527
# std        0.700282     20.380682      4.249027      3.356903   2377.322237
# min        1.000000      1.000000      1.000000      1.000000      0.000000
# 25%        1.000000     22.000000      5.000000      3.666667   2411.875000
# 50%        1.666667     32.000000      7.000000      5.333333   3085.900000
# 75%        2.000000     45.000000     10.000000      7.500000   4306.600000
# max        6.166667    212.000000     39.000000     35.333333  44590.330000
#
#           月统筹金额_AVG     月药品金额_MAX     月药品金额_AVG   医院_就诊天数_MAX   医院_就诊天数_AVG  \
# count  15207.000000  15207.000000  15207.000000  15207.000000  15207.000000
# mean    2653.839829   3425.523891   2479.217903     25.849083     18.711838
# std     1583.191785   2014.120367   1386.422612     16.065884     13.544779
# min        0.000000      0.000000      0.000000      1.000000      1.000000
# 25%     1793.364167   2349.940000   1756.635833     14.000000     10.666667
# 50%     2232.940000   2970.700000   2169.371667     23.000000     15.000000
# 75%     3042.710000   4010.270000   2879.246667     32.000000     22.500000
# max    37403.050000  77841.700000  37945.940000    180.000000    172.000000
#
#           医院_统筹金_MAX     医院_统筹金_AVG      医院_药品_MAX      医院_药品_AVG  \
# count   15207.000000   15207.000000   15207.000000   15207.000000
# mean    12124.854867    8810.837487   11289.192690    8061.864228
# std      8419.918123    7750.332475    7212.893977    6308.173180
# min         0.000000       0.000000       0.000000       0.000000
# 25%      7646.125000    4750.807500    7492.250000    4611.177500
# 50%     10241.920000    6518.540000   10077.010000    6338.940000
# 75%     13707.115000   10473.712500   13249.410000   10045.670000
# max    100726.770000  100726.770000  189729.700000  151598.250000
#
#             医院编码_NN        顺序号_NN     交易时间DD_NN  交易时间YYYY_NN  交易时间YYYYMM_NN  \
# count  15207.000000  15207.000000  15207.000000      15207.0   15207.000000
# mean       2.170185     87.114816     33.392648          1.0       5.830802
# std        1.019137     51.427458     18.454815          0.0       0.673216
# min        1.000000      1.000000      1.000000          1.0       1.000000
# 25%        1.000000     55.000000     20.000000          1.0       6.000000
# 50%        2.000000     78.000000     30.000000          1.0       6.000000
# 75%        3.000000    107.000000     42.000000          1.0       6.000000
# max        9.000000    945.000000    180.000000          1.0       7.000000
#
#        住院天数_SUM    个人账户金额_SUM     统筹支付金额_SUM        ALL_SUM  可用账户报销金额_SUM  \
# count   15207.0  15207.000000   15207.000000   15207.000000  15207.000000
# mean        0.0   2157.627664   15554.351199   17538.405795   2046.556829
# std         0.0   1977.760114    9041.761172   10470.791665   1932.860692
# min         0.0      1.450000       0.000000       4.000000      0.000000
# 25%         0.0   1209.315000   10581.665000   11937.690000   1143.935000
# 50%         0.0   1614.350000   13224.160000   14759.950000   1516.370000
# 75%         0.0   2365.710000   18047.370000   20069.940000   2209.820000
# max         0.0  45518.610000  100906.300000  192104.390000  45518.580000
#
#          药品费发生金额_SUM   药品费自费金额_SUM    药品费申报金额_SUM   贵重药品发生金额_SUM  \
# count   15207.000000  15207.000000   15207.000000   15207.000000
# mean    14604.246548     76.621660   14373.851475    2485.758351
# std      8239.203383    190.548049    8008.984776    5541.159422
# min         0.000000      0.000000       0.000000       0.000000
# 25%     10370.230000      0.030000   10242.095000       0.000000
# 50%     12835.690000      7.890000   12693.760000     992.300000
# 75%     17123.625000     64.810000   16863.940000    2777.600000
# max    190317.550000   7752.530000  189335.700000  189729.700000
#
#        中成药费发生金额_SUM  中草药费发生金额_SUM   检查费发生金额_SUM   检查费自费金额_SUM   检查费申报金额_SUM  \
# count  15207.000000  15207.000000  15207.000000  15207.000000  15207.000000
# mean    3266.477386   2424.308565    588.386348      9.335477    571.979003
# std     3258.538088   3316.246334    888.115772     80.730222    838.333787
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%     1460.960000      0.000000     16.500000      0.000000     16.250000
# 50%     2697.110000    607.180000    270.000000      0.000000    270.000000
# 75%     4218.290000   4217.015000    769.000000      0.000000    759.000000
# max    87947.560000  34412.120000  13941.000000   3864.000000  10685.400000
#
#         贵重检查费金额_SUM   治疗费发生金额_SUM   治疗费自费金额_SUM   治疗费申报金额_SUM   手术费发生金额_SUM  \
# count  15207.000000  15207.000000  15207.000000  15207.000000  15207.000000
# mean      58.852436   2025.959173      8.339504   1995.725028      7.656671
# std      306.160399   6176.982910     86.238144   6065.083419    160.822574
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.000000    214.000000      0.000000    211.000000      0.000000
# 50%        0.000000    394.000000      0.000000    387.000000      0.000000
# 75%        0.000000    752.000000      0.000000    735.000000      0.000000
# max     7670.000000  52120.000000   7750.000000  51039.500000   7975.000000
#
#         手术费自费金额_SUM   手术费申报金额_SUM   床位费发生金额_SUM   床位费申报金额_SUM  医用材料发生金额_SUM  \
# count  15207.000000  15207.000000  15207.000000  15207.000000   15207.00000
# mean       0.072993      7.582922      5.056652      5.012790     299.36710
# std        5.461227    160.726692     30.513411     30.455464     501.27406
# min        0.000000      0.000000      0.000000      0.000000       0.00000
# 25%        0.000000      0.000000      0.000000      0.000000       7.30000
# 50%        0.000000      0.000000      0.000000      0.000000     184.70000
# 75%        0.000000      0.000000      0.000000      0.000000     467.27000
# max      600.000000   7975.000000    795.000000    795.000000   31303.10000
#
#        高价材料发生金额_SUM  医用材料费自费金额_SUM  成分输血申报金额_SUM    其它发生金额_SUM    其它申报金额_SUM  \
# count  15207.000000   15207.000000  15207.000000  15207.000000  15207.000000
# mean      14.252362       8.917600     10.158217      7.733303      0.041823
# std      412.783816      72.034787    452.003023     30.325444      3.229824
# min        0.000000       0.000000      0.000000      0.000000      0.000000
# 25%        0.000000       0.000000      0.000000      0.000000      0.000000
# 50%        0.000000       0.000000      0.000000      0.000000      0.000000
# 75%        0.000000       0.000000      0.000000      6.000000      0.000000
# max    31270.800000    3013.600000  39718.000000    750.000000    375.000000
#
#        一次性医用材料申报金额_SUM   起付线标准金额_MAX  起付标准以上自负比例金额_SUM  医疗救助个人按比例负担金额_SUM  \
# count     15207.000000  15207.000000      15207.000000       15207.000000
# mean        263.423845      7.299928       2159.459475          31.889539
# std         459.990092    111.726648       1899.904598         545.211376
# min           0.000000      0.000000          0.000000           0.000000
# 25%           1.200000      0.000000       1224.965000           0.000000
# 50%         129.000000      0.000000       1578.880000           0.000000
# 75%         442.400000      0.000000       2269.910000           0.000000
# max       28257.540000   3638.480000      19880.800000       33010.870000
#
#        最高限额以上金额_SUM  基本统筹基金支付金额_SUM  公务员医疗补助基金支付金额_SUM  城乡救助补助金额_SUM  \
# count  15207.000000    15207.000000       15207.000000  15207.000000
# mean       0.083263    14931.061164          44.904947    288.165109
# std       10.267712     7863.593900         408.747822   1163.396476
# min        0.000000        0.000000           0.000000      0.000000
# 25%        0.000000    10447.620000           0.000000      0.000000
# 50%        0.000000    12974.240000           0.000000      0.000000
# 75%        0.000000    17464.345000           0.000000      0.000000
# max     1266.180000    83927.120000       11851.690000  30362.940000
#
#        基本个人账户支付_SUM   非账户支付金额_SUM     本次审批金额_SUM    补助审批金额_SUM   医疗救助医院申请_SUM  \
# count  15207.000000  15207.000000   15207.000000  15207.000000   15207.000000
# mean     126.855880   2030.771784   17227.659632    454.424599     127.558238
# std      205.435253   1963.902405   10159.610973   1691.842767    2180.847893
# min        0.000000      0.000000       3.000000      0.000000       0.000000
# 25%        0.000000   1091.795000   11785.170000      0.000000       0.000000
# 50%      105.510000   1491.980000   14577.890000      0.000000       0.000000
# 75%      165.995000   2219.315000   19742.905000      0.000000       0.000000
# max     8297.080000  45345.100000  189768.500000  37953.700000  132043.470000
#
#          残疾军人补助_SUM    民政救助补助_SUM    城乡优抚补助_SUM   出院诊断病种名称_NN  出院诊断LENTH_MAX  \
# count  15207.000000  15207.000000  15207.000000  15207.000000   15207.000000
# mean       3.006277    285.992322      1.221380      5.238969      25.401854
# std      194.772071   1154.443280     79.423567      2.676710      12.777580
# min        0.000000      0.000000      0.000000      0.000000       0.000000
# 25%        0.000000      0.000000      0.000000      3.000000      17.000000
# 50%        0.000000      0.000000      0.000000      5.000000      25.000000
# 75%        0.000000      0.000000      0.000000      7.000000      33.000000
# max    16965.630000  30362.940000   8913.440000     24.000000      86.000000
#
#          药品在总金额中的占比     个人支付的药品占比   检查总费用在总金额占比    个人支付检查费用占比    治疗费用在总金额占比  \
# count  15207.000000  15207.000000  15207.000000  15207.000000  15207.000000
# mean       0.858612      0.005472      0.039600      0.005243      0.076345
# std        0.162938      0.014051      0.065110      0.031884      0.148248
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.848385      0.000002      0.001132      0.000000      0.015730
# 50%        0.907703      0.000555      0.017133      0.000000      0.027764
# 75%        0.945527      0.004721      0.050589      0.000000      0.050215
# max        1.000000      0.689375      0.962401      1.000000      1.000000
#
#          个人支付治疗费用占比       BZ_民政救助       BZ_城乡优抚          是否挂号      RES
# count  15207.000000  15207.000000  15207.000000  15207.000000  15207.0
# mean       0.010862      0.137831      0.000526      0.254422      0.0
# std        0.057756      0.344734      0.022931      0.435550      0.0
# min        0.000000      0.000000      0.000000      0.000000      0.0
# 25%        0.000000      0.000000      0.000000      0.000000      0.0
# 50%        0.000000      0.000000      0.000000      0.000000      0.0
# 75%        0.000000      0.000000      0.000000      1.000000      0.0
# max        0.883652      1.000000      1.000000      1.000000      0.0

# %% [markdown]
# # 空值、异常值
# - 没有空值，部分特征有很多为0的值

# %%
# 分别统计欺诈（RES=1）和非欺诈（RES=0）中特征列含0的个数
fraud_zero_counts = (df[df['RES'] == 1] == 0).sum()
non_fraud_zero_counts = (df[df['RES'] == 0] == 0).sum()

# 筛选出包含0的特征
fraud_zero_counts = fraud_zero_counts[fraud_zero_counts > 0]
non_fraud_zero_counts = non_fraud_zero_counts[non_fraud_zero_counts > 0]

print("RES=1:\n",fraud_zero_counts)
print("________________________")
print("RES=0:\n",non_fraud_zero_counts)
# Out:
# RES=1:
#  一天去两家医院的天数           480
# 月统筹金额_MAX              1
# 月统筹金额_AVG              1
# 医院_统筹金_MAX             1
# 医院_统筹金_AVG             1
# 住院天数_SUM             793
# 统筹支付金额_SUM             1
# 可用账户报销金额_SUM           1
# 药品费自费金额_SUM          115
# 贵重药品发生金额_SUM         195
# 中成药费发生金额_SUM          94
# 中草药费发生金额_SUM         447
# 检查费发生金额_SUM          164
# 检查费自费金额_SUM          656
# 检查费申报金额_SUM          164
# 贵重检查费金额_SUM          681
# 治疗费自费金额_SUM          676
# 手术费发生金额_SUM          786
# 手术费自费金额_SUM          790
# 手术费申报金额_SUM          788
# 床位费发生金额_SUM          724
# 床位费申报金额_SUM          726
# 医用材料发生金额_SUM         188
# 高价材料发生金额_SUM         776
# 医用材料费自费金额_SUM        568
# 成分输血申报金额_SUM         792
# 其它发生金额_SUM           481
# 其它申报金额_SUM           791
# 一次性医用材料申报金额_SUM      231
# 起付线标准金额_MAX          784
# 起付标准以上自负比例金额_SUM       4
# 医疗救助个人按比例负担金额_SUM    645
# 最高限额以上金额_SUM         793
# 基本统筹基金支付金额_SUM         4
# 公务员医疗补助基金支付金额_SUM    771
# 城乡救助补助金额_SUM         598
# 基本个人账户支付_SUM         315
# 补助审批金额_SUM           596
# 医疗救助医院申请_SUM         644
# 残疾军人补助_SUM           792
# 民政救助补助_SUM           599
# 城乡优抚补助_SUM           792
# 出院诊断病种名称_NN           28
# 出院诊断LENTH_MAX         28
# 个人支付的药品占比            115
# 检查总费用在总金额占比          164
# 个人支付检查费用占比           656
# 个人支付治疗费用占比           676
# BZ_民政救助              599
# BZ_城乡优抚              792
# 是否挂号                 610
# dtype: int64
# ________________________
# RES=0:
#  一天去两家医院的天数           12360
# 月统筹金额_MAX                8
# 月统筹金额_AVG                8
# 月药品金额_MAX               47
# 月药品金额_AVG               47
# 医院_统筹金_MAX               8
# 医院_统筹金_AVG               8
# 医院_药品_MAX               47
# 医院_药品_AVG               47
# 住院天数_SUM             15207
# 统筹支付金额_SUM               8
# 可用账户报销金额_SUM             5
# 药品费发生金额_SUM             47
# 药品费自费金额_SUM           3520
# 药品费申报金额_SUM             47
# 贵重药品发生金额_SUM          6436
# 中成药费发生金额_SUM          1600
# 中草药费发生金额_SUM          6717
# 检查费发生金额_SUM           3497
# 检查费自费金额_SUM          13839
# 检查费申报金额_SUM           3499
# 贵重检查费金额_SUM          14118
# 治疗费发生金额_SUM             45
# 治疗费自费金额_SUM          12675
# 治疗费申报金额_SUM             45
# 手术费发生金额_SUM          15109
# 手术费自费金额_SUM          15192
# 手术费申报金额_SUM          15120
# 床位费发生金额_SUM          14425
# 床位费申报金额_SUM          14461
# 医用材料发生金额_SUM          2850
# 高价材料发生金额_SUM         15140
# 医用材料费自费金额_SUM        11531
# 成分输血申报金额_SUM         15191
# 其它发生金额_SUM            9136
# 其它申报金额_SUM           15198
# 一次性医用材料申报金额_SUM       3597
# 起付线标准金额_MAX          15123
# 起付标准以上自负比例金额_SUM        14
# 医疗救助个人按比例负担金额_SUM    15077
# 最高限额以上金额_SUM         15206
# 基本统筹基金支付金额_SUM          14
# 公务员医疗补助基金支付金额_SUM    14885
# 城乡救助补助金额_SUM         13103
# 基本个人账户支付_SUM          5654
# 非账户支付金额_SUM              6
# 补助审批金额_SUM           13098
# 医疗救助医院申请_SUM         15077
# 残疾军人补助_SUM           15202
# 民政救助补助_SUM           13111
# 城乡优抚补助_SUM           15199
# 出院诊断病种名称_NN            327
# 出院诊断LENTH_MAX          327
# 药品在总金额中的占比              47
# 个人支付的药品占比             3520
# 检查总费用在总金额占比           3497
# 个人支付检查费用占比           13839
# 治疗费用在总金额占比              45
# 个人支付治疗费用占比           12675
# BZ_民政救助              13111
# BZ_城乡优抚              15199
# 是否挂号                 11338
# RES                  15207
# dtype: int64

# %% [markdown]
# # 统计分析

# %% [markdown]
# ## 就诊行为

# %%
columns_of_interest = ['就诊的月数', '一天去两家医院的天数', '月就诊天数_MAX', '月就诊医院数_MAX', '就诊次数_SUM', '月就诊次数_MAX']

# Creating a figure for multiple subplots
fig, axes = plt.subplots(nrows=3, ncols=2, figsize=(15, 15))
axes = axes.flatten()  # Flatten to easily index them

for i, col in enumerate(columns_of_interest):
    # Grouping by each column and counting occurrences of RES values
    grouped_data = data.groupby([col, 'RES']).size().unstack(fill_value=0)
    grouped_data.columns = ['非欺诈个数', '欺诈个数']

    axes[i].bar(grouped_data.index, grouped_data['非欺诈个数'], width=0.4, label='非欺诈个数', align='center')
    axes[i].bar(grouped_data.index + 0.4, grouped_data['欺诈个数'], width=0.4, label='欺诈个数', align='center')

    axes[i].set_xlabel(col)
    axes[i].set_ylabel('个数')
    axes[i].set_title(f'{col}下的欺诈与非欺诈个数对比')
    axes[i].legend()

plt.tight_layout()
plt.show()

# %%
total_fraudulent = data['RES'].sum()
total_non_fraudulent = len(data) - total_fraudulent

# Function to calculate the proportion and plot
def plot_proportion_and_calculate(data, column, total_fraudulent, total_non_fraudulent):
    # Grouping by the column and counting occurrences of RES values
    grouped_data = data.groupby([column, 'RES']).size().unstack(fill_value=0)
    
    # Calculating the proportion
    grouped_data['欺诈比例'] = grouped_data[1] / total_fraudulent
    grouped_data['非欺诈比例'] = grouped_data[0] / total_non_fraudulent

    return grouped_data[['欺诈比例', '非欺诈比例']]

# Creating a figure for multiple subplots
fig, axes = plt.subplots(nrows=3, ncols=2, figsize=(15, 15))
axes = axes.flatten()  # Flatten to easily index them

proportions = {}

# Calculating proportions and plotting for each column
for i, col in enumerate(columns_of_interest):
    prop = plot_proportion_and_calculate(data, col, total_fraudulent, total_non_fraudulent)
    proportions[col] = prop

    # Plotting
    axes[i].bar(prop.index, prop['非欺诈比例'], width=0.4, label='非欺诈比例', align='center')
    axes[i].bar(prop.index + 0.4, prop['欺诈比例'], width=0.4, label='欺诈比例', align='center')

    # Setting labels and titles
    axes[i].set_xlabel(col)
    axes[i].set_ylabel('比例')
    axes[i].set_title(f'{col}下的欺诈与非欺诈比例')
    axes[i].legend()

# Adjust layout
plt.tight_layout()
plt.show()

print(proportions)
# Out:
# {'就诊的月数': RES        欺诈比例     非欺诈比例
# 就诊的月数
# 1      0.011349  0.006773
# 2      0.035309  0.006970
# 3      0.037831  0.009995
# 4      0.031526  0.016637
# 5      0.058008  0.044322
# 6      0.824716  0.915171
# 7      0.001261  0.000132, '一天去两家医院的天数': RES             欺诈比例     非欺诈比例
# 一天去两家医院的天数
# 0           0.605296  0.812784
# 4           0.045397  0.034458
# 5           0.027743  0.025449
# 6           0.023960  0.023016
# 7           0.018916  0.017032
# 8           0.021438  0.016111
# 9           0.015132  0.011902
# 10          0.015132  0.012494
# 11          0.012610  0.009930
# 12          0.015132  0.008680
# 13          0.007566  0.007365
# 14          0.008827  0.004537
# 15          0.006305  0.002893
# 16          0.008827  0.002499
# 17          0.016393  0.001644
# 18          0.007566  0.001907
# 19          0.003783  0.001381
# 20          0.006305  0.000921
# 21          0.007566  0.000855
# 22          0.003783  0.000658
# 23          0.008827  0.000263
# 24          0.010088  0.000658
# 25          0.006305  0.000197
# 26          0.006305  0.000460
# 27          0.005044  0.000263
# 28          0.005044  0.000132
# 29          0.005044  0.000263
# 30          0.003783  0.000000
# 31          0.006305  0.000000
# 32          0.002522  0.000132
# 33          0.002522  0.000066
# 34          0.002522  0.000197
# 35          0.003783  0.000000
# 36          0.001261  0.000000
# 37          0.005044  0.000132
# 38          0.001261  0.000000
# 39          0.001261  0.000066
# 40          0.003783  0.000263
# 41          0.002522  0.000066
# 42          0.002522  0.000000
# 43          0.002522  0.000066
# 44          0.001261  0.000000
# 45          0.002522  0.000000
# 46          0.001261  0.000066
# 47          0.001261  0.000066
# 48          0.002522  0.000000
# 49          0.000000  0.000066
# 53          0.001261  0.000000
# 54          0.001261  0.000066
# 55          0.001261  0.000000
# 56          0.001261  0.000000
# 63          0.001261  0.000000
# 65          0.001261  0.000000
# 66          0.001261  0.000000
# 67          0.001261  0.000000
# 68          0.001261  0.000000
# 69          0.001261  0.000000
# 72          0.002522  0.000000
# 74          0.002522  0.000000
# 77          0.001261  0.000000
# 86          0.001261  0.000000
# 88          0.001261  0.000000
# 93          0.001261  0.000000
# 94          0.001261  0.000000
# 108         0.001261  0.000000, '月就诊天数_MAX': RES            欺诈比例     非欺诈比例
# 月就诊天数_MAX
# 1          0.001261  0.011245
# 2          0.022699  0.029986
# 3          0.041614  0.074702
# 4          0.063052  0.082988
# 5          0.081967  0.124416
# 6          0.063052  0.124482
# 7          0.049180  0.118038
# 8          0.040353  0.104360
# 9          0.029004  0.080226
# 10         0.031526  0.062669
# 11         0.035309  0.045637
# 12         0.037831  0.034918
# 13         0.041614  0.027487
# 14         0.080706  0.026304
# 15         0.032787  0.016177
# 16         0.045397  0.011574
# 17         0.029004  0.006773
# 18         0.036570  0.005590
# 19         0.035309  0.003617
# 20         0.041614  0.002433
# 21         0.023960  0.002236
# 22         0.017654  0.001381
# 23         0.016393  0.000855
# 24         0.020177  0.000526
# 25         0.012610  0.000526
# 26         0.013871  0.000329
# 27         0.012610  0.000197
# 28         0.007566  0.000132
# 29         0.006305  0.000066
# 30         0.008827  0.000000
# 31         0.020177  0.000132, '月就诊医院数_MAX': RES             欺诈比例     非欺诈比例
# 月就诊医院数_MAX
# 1           0.220681  0.286184
# 2           0.296343  0.436181
# 3           0.277427  0.211613
# 4           0.136192  0.052213
# 5           0.040353  0.011376
# 6           0.017654  0.002170
# 7           0.010088  0.000263
# 8           0.001261  0.000000, '就诊次数_SUM': RES           欺诈比例     非欺诈比例
# 就诊次数_SUM
# 1         0.000000  0.004011
# 2         0.000000  0.003222
# 3         0.000000  0.002893
# 4         0.000000  0.003288
# 5         0.001261  0.003683
# ...            ...       ...
# 257       0.001261  0.000000
# 268       0.001261  0.000000
# 273       0.001261  0.000000
# 279       0.001261  0.000000
# 307       0.001261  0.000000
#
# [190 rows x 2 columns], '月就诊次数_MAX': RES            欺诈比例     非欺诈比例
# 月就诊次数_MAX
# 1          0.001261  0.011179
# 2          0.021438  0.028342
# 3          0.039092  0.066811
# 4          0.050441  0.074834
# 5          0.074401  0.114881
# 6          0.063052  0.119550
# 7          0.049180  0.110410
# 8          0.044136  0.101466
# 9          0.023960  0.083120
# 10         0.032787  0.066417
# 11         0.029004  0.048070
# 12         0.026482  0.038403
# 13         0.039092  0.030381
# 14         0.075662  0.029723
# 15         0.037831  0.020714
# 16         0.031526  0.013481
# 17         0.031526  0.010719
# 18         0.029004  0.007431
# 19         0.025221  0.005458
# 20         0.018916  0.004800
# 21         0.017654  0.003551
# 22         0.018916  0.001710
# 23         0.008827  0.001841
# 24         0.021438  0.001512
# 25         0.017654  0.001118
# 26         0.017654  0.000986
# 27         0.003783  0.000789
# 28         0.017654  0.000460
# 29         0.017654  0.000395
# 30         0.012610  0.000263
# 31         0.008827  0.000329
# 32         0.008827  0.000263
# 33         0.005044  0.000000
# 34         0.011349  0.000263
# 35         0.006305  0.000000
# 36         0.005044  0.000197
# 37         0.002522  0.000000
# 38         0.001261  0.000066
# 39         0.003783  0.000066
# 40         0.003783  0.000000
# 41         0.005044  0.000000
# 42         0.002522  0.000000
# 43         0.002522  0.000000
# 44         0.002522  0.000000
# 45         0.001261  0.000000
# 46         0.002522  0.000000
# 47         0.002522  0.000000
# 49         0.005044  0.000000
# 54         0.005044  0.000000
# 55         0.001261  0.000000
# 56         0.001261  0.000000
# 60         0.003783  0.000000
# 61         0.002522  0.000000
# 64         0.003783  0.000000
# 66         0.001261  0.000000
# 67         0.001261  0.000000
# 75         0.001261  0.000000}

# %% [markdown]
# - 一天去两家医院的天数是否超过4
# - 月就诊天数是否超过14
# - 月就诊医院数是否超过3
# - 就诊总次数是否大于60
# - 月就诊次数最大值是否超过15

# %% [markdown]
# ### 就诊欺诈系数
#
# 计算医院编码_NN中欺诈的占比：比如医院编号为3，欺诈次数为12，非欺诈次数为12，其就诊欺诈系数为12/(12+36)=0.25

# %%
# 计算每个医院的就诊欺诈系数
fraud_counts = data[data['RES'] == 1].groupby('医院编码_NN').size()
total_counts = data.groupby('医院编码_NN').size()
fraud_ratio = fraud_counts / total_counts

# 处理可能出现的NaN值（当医院没有欺诈记录时）
fraud_ratio = fraud_ratio.fillna(0)

# 输出计算结果
fraud_ratio_sorted = fraud_ratio.sort_values(ascending=False)

# 可视化结果
plt.figure(figsize=(15, 8))
fraud_ratio_sorted.plot(kind='bar')
plt.title('每个医院的就诊欺诈系数')
plt.xlabel('医院编码')
plt.ylabel('就诊欺诈系数')
plt.show()

fraud_ratio_sorted.head(10)  # 显示前10个医院的欺诈系数
# Out:
# 医院编码_NN
# 9    0.666667
# 7    0.433333
# 6    0.228916
# 8    0.200000
# 5    0.109422
# 4    0.102395
# 3    0.061547
# 1    0.038050
# 2    0.032950
# dtype: float64

# %%
hospital_codes_fraud_counts = data[data['RES'] == 1]['医院编码_NN'].value_counts()

# Count the occurrence of each hospital code within the non-fraudulent category
hospital_codes_nonfraud_counts = data[data['RES'] == 0]['医院编码_NN'].value_counts()

# Display the counts for both categories
hospital_codes_fraud_counts, hospital_codes_nonfraud_counts
# Out:
# (医院编码_NN
#  3    222
#  2    209
#  1    167
#  4    124
#  5     36
#  6     19
#  7     13
#  9      2
#  8      1
#  Name: count, dtype: int64,
#  医院编码_NN
#  2    6134
#  1    4222
#  3    3385
#  4    1087
#  5     293
#  6      64
#  7      17
#  8       4
#  9       1
#  Name: count, dtype: int64)

# %% [markdown]
# ### 诊断欺诈系数

# %%
fraud_counts_diagnosis = data[data['RES'] == 1].groupby('出院诊断病种名称_NN').size()
total_counts_diagnosis = data.groupby('出院诊断病种名称_NN').size()

# 直接计算欺诈次数与总次数的比例
simple_fraud_ratio_diagnosis = fraud_counts_diagnosis / total_counts_diagnosis

# 处理可能出现的NaN值
simple_fraud_ratio_diagnosis = simple_fraud_ratio_diagnosis.fillna(0)

# 对结果进行排序
simple_fraud_ratio_diagnosis_sorted = simple_fraud_ratio_diagnosis.sort_values(ascending=False)

# 合并欺诈次数和非欺诈次数
fraud_non_fraud_counts_diagnosis = pd.DataFrame({
    'Fraud Counts': fraud_counts_diagnosis,
    'Non-Fraud Counts': total_counts_diagnosis - fraud_counts_diagnosis,
    'Fraud Ratio': simple_fraud_ratio_diagnosis
})

fraud_non_fraud_counts_diagnosis_sorted = fraud_non_fraud_counts_diagnosis.sort_values(by='Fraud Ratio', ascending=False)

# %%
fraud_non_fraud_counts_diagnosis_sorted.head(30)
# Out:
#              Fraud Counts  Non-Fraud Counts  Fraud Ratio
# 出院诊断病种名称_NN
# 39                    1.0               0.0     1.000000
# 34                    1.0               0.0     1.000000
# 32                    3.0               0.0     1.000000
# 28                    1.0               0.0     1.000000
# 25                    2.0               0.0     1.000000
# 23                    3.0               0.0     1.000000
# 21                    3.0               0.0     1.000000
# 22                    4.0               1.0     0.800000
# 17                   16.0              14.0     0.533333
# 20                    2.0               2.0     0.500000
# 19                    6.0               6.0     0.500000
# 18                    5.0               5.0     0.500000
# 15                   22.0              27.0     0.448980
# 16                    9.0              23.0     0.281250
# 14                   15.0              49.0     0.234375
# 12                   29.0             151.0     0.161111
# 13                   17.0             115.0     0.128788
# 11                   35.0             248.0     0.123675
# 10                   49.0             400.0     0.109131
# 0                    28.0             327.0     0.078873
# 1                     3.0              47.0     0.060000
# 8                    48.0             936.0     0.048780
# 9                    30.0             626.0     0.045732
# 7                    70.0            1482.0     0.045103
# 2                    68.0            1674.0     0.039036
# 3                    78.0            1985.0     0.037809
# 5                   100.0            2569.0     0.037467
# 4                    86.0            2597.0     0.032054
# 6                    59.0            1920.0     0.029813
# 24                    NaN               NaN     0.000000

# %% [markdown]
# ## 费用基础

# %% [markdown]
# ### 药品金额

# %%
# 分布

df[['月药品金额_MAX','月药品金额_AVG','医院_药品_MAX','医院_药品_AVG','药品费发生金额_SUM',
    '药品费自费金额_SUM','药品费申报金额_SUM','贵重药品发生金额_SUM','中成药费发生金额_SUM',
    '中草药费发生金额_SUM'
    ]].describe()
# Out:
#           月药品金额_MAX     月药品金额_AVG      医院_药品_MAX      医院_药品_AVG  \
# count  16000.000000  16000.000000   16000.000000   16000.000000
# mean    3631.380422   2602.861947   11696.530186    8257.661369
# std     2682.941527   1776.066792    8555.770743    6948.782110
# min        0.000000      0.000000       0.000000       0.000000
# 25%     2351.600000   1751.854583    7449.155000    4583.521250
# 50%     3001.875000   2184.220833   10104.070000    6364.521667
# 75%     4119.525000   2948.170000   13465.987500   10196.982500
# max    77841.700000  38656.056670  203167.880000  151598.250000
#
#          药品费发生金额_SUM   药品费自费金额_SUM    药品费申报金额_SUM   贵重药品发生金额_SUM  \
# count   16000.000000  16000.000000   16000.000000   16000.000000
# mean    15275.711085     80.603902   15023.718634    2709.672334
# std     10536.443992    215.586310   10240.500007    6256.166307
# min         0.000000      0.000000       0.000000       0.000000
# 25%     10313.175000      0.040000   10190.357500       0.000000
# 50%     12876.790000      8.250000   12740.265000    1094.870000
# 75%     17441.580000     67.642500   17189.670000    2893.660000
# max    231936.340000  11165.130000  224594.610000  189729.700000
#
#         中成药费发生金额_SUM  中草药费发生金额_SUM
# count   16000.000000  16000.000000
# mean     3401.571010   2389.157068
# std      3818.560983   3333.948935
# min         0.000000      0.000000
# 25%      1440.892500      0.000000
# 50%      2703.155000    537.515000
# 75%      4280.675000   4180.015000
# max    115738.150000  34412.120000

# %%
columns_to_visualize = [
    '月药品金额_MAX', '月药品金额_AVG', '医院_药品_MAX', '医院_药品_AVG', '药品费发生金额_SUM',
    '药品费自费金额_SUM', '药品费申报金额_SUM', '贵重药品发生金额_SUM', '中成药费发生金额_SUM',
    '中草药费发生金额_SUM'
]

# Creating subplots for each feature
fig, axes = plt.subplots(nrows=len(columns_to_visualize), ncols=2, figsize=(12, 4*len(columns_to_visualize)), sharex='col')
bins = 30

# Plotting histograms for each feature
for i, col in enumerate(columns_to_visualize):
    # Histogram for fraudulent cases
    axes[i, 0].hist(data[col][data['RES'] == 1].values, bins=bins)
    axes[i, 0].set_title(f"欺诈 - {col}")
    axes[i, 0].set_ylabel("Distribution")
    axes[i, 0].set_yscale('log')

    # Histogram for non-fraudulent cases
    axes[i, 1].hist(data[col][data['RES'] == 0].values, bins=bins)
    axes[i, 1].set_title(f"非欺诈 - {col}")
    axes[i, 1].set_ylabel("Distribution")
    axes[i, 1].set_yscale('log')

# Setting common x-label
plt.xlabel("总计")
plt.tight_layout()
plt.show()

# %%
## 不同类别下的分布

import ipywidgets as widgets
from IPython.display import display
import matplotlib.gridspec as gridspec

selected_features = [
    '月药品金额_MAX', '月药品金额_AVG', '医院_药品_MAX', '医院_药品_AVG', '药品费发生金额_SUM',
    '药品费自费金额_SUM', '药品费申报金额_SUM', '贵重药品发生金额_SUM', '中成药费发生金额_SUM',
    '中草药费发生金额_SUM'
]

# Creating subplots for each selected feature
plt.figure(figsize=(12, len(selected_features) * 4))
gs = gridspec.GridSpec(len(selected_features), 1)
bins = 50

for i, feature in enumerate(selected_features):
    ax = plt.subplot(gs[i])
    sns.distplot(data[feature][data['RES'] == 1].values, bins=bins, label='Fraud', kde=False, norm_hist=True)
    sns.distplot(data[feature][data['RES'] == 0].values, bins=bins, label='Normal', kde=False, norm_hist=True)
    ax.set_xlabel('')
    ax.set_title(f'{feature}')
    ax.legend()

plt.show()

# %% [markdown]
# **图表分析**
#
# 月药品金额_MAX（月最高药品金额）：此图表比较了欺诈案例和非欺诈案例的月最高药品金额。欺诈分布中的特定模式或异常值可能表明这些案例中存在异常的支出行为。
#
# 月药品金额_AVG（月平均药品金额）：显示月平均药品金额。两组之间平均支出的差异可能表明，与正常案例相比，欺诈案例在药品使用上要么大大过量，要么大大不足。
# - 与出院诊断结合成新特征，部分小病可能存在药物过量
#
# 医院_药品_MAX（每次医院访问的最高药品金额）：表示每次医院访问的最高药品金额。欺诈案例中较高的最大值可能表明存在过度收费或过度开药的情况。
#
# 医院_药品_AVG（每次医院访问的平均药品金额）：与最高金额类似，但侧重于平均值，此图表揭示两组之间每次医院访问的典型成本差异。
#
# 药品费发生金额_SUM（药品总费用）：代表药品总费用。这里的大差异可能是欺诈的强有力指标，尤其是如果欺诈案例的费用明显更高的话。
#
# 药品费自费金额_SUM（药品自付总费用）：患者自己支付的总金额。这里的模式可能表明欺诈案例是否更可能涉及更高的自付费用。
#
# 药品费申报金额_SUM（药品申报总费用）：从保险或报销中申报的总金额。这里的差异在识别欺诈活动（如过度申报）方面可能至关重要。
#
# 贵重药品发生金额_SUM（贵重药品总费用）：显示在更昂贵的药品上的支出。欺诈案例中异常高的值可能表明高成本药物的滥用或过度使用。
#
# 中成药费发生金额_SUM（中成药总费用）：关注中成药的费用。显著的差异可能表明与这类药品相关的特定欺诈模式。
#
# 中草药费发生金额_SUM（中草药总费用）：与中成药类似，这里的任何不寻常模式可能表明涉及中草药的欺诈活动。

# %% [markdown]
# ### 总体费用

# %%
# 利用ALL_SUM统计计算其异常值

category_0_data = df[df['RES'] == 0]
category_1_data = df[df['RES'] == 1]

# Calculate IQR for 'ALL_SUM' in category 0 data
Q1 = category_0_data['ALL_SUM'].quantile(0.25)
Q3 = category_0_data['ALL_SUM'].quantile(0.75)
IQR = Q3 - Q1

# Define the lower and upper bound for outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Identify outliers
outliers = category_0_data[(category_0_data['ALL_SUM'] < lower_bound) | (category_0_data['ALL_SUM'] > upper_bound)]
outlier_count = outliers.shape[0]

outlier_count, lower_bound, upper_bound
# Out:
# (1095, -260.68500000000313, 32268.315000000006)

# %%
# Calculate 'ALL_SUM' for category 1 data
category_1_data['ALL_SUM'] = category_1_data['个人账户金额_SUM'] + category_1_data['统筹支付金额_SUM']

# Identify outliers in category 1 data using the IQR from category 0 data
category_1_outliers = category_1_data[(category_1_data['ALL_SUM'] < lower_bound) | (category_1_data['ALL_SUM'] > upper_bound)]
category_1_outlier_count = category_1_outliers.shape[0]

category_1_outlier_count
# Out:
# 351

# %%
# 计算个人账户使用异常指数
data['个人账户使用异常指数'] = data['可用账户报销金额_SUM'] / data['个人账户金额_SUM']

# 为了避免除以零的错误，将个人账户金额为零的记录的异常指数设为NaN
data['个人账户使用异常指数'] = data['个人账户使用异常指数'].replace([float('inf'), -float('inf')], float('nan'))

# 检查计算结果的分布
account_usage_summary = data['个人账户使用异常指数'].describe()

account_usage_summary
# Out:
# count    16000.000000
# mean         0.944487
# std          0.094698
# min          0.000000
# 25%          0.936498
# 50%          0.984567
# 75%          0.997029
# max          1.000000
# Name: 个人账户使用异常指数, dtype: float64

# %%
# 可视化两个类别的个人账户使用异常指数
sns.boxplot(x='RES', y='个人账户使用异常指数', data=data)
plt.title('个人账户使用异常指数分布 - 欺诈 vs 非欺诈')
plt.show()

# %% [markdown]
# 正常行为（'RES' = 0）：这一类别中，个人账户使用异常指数大多数集中在0.9到1的区域。这表明在这个群体中，大部分人的可用账户报销金额与个人账户金额的比例相对较高，表现出一致性。
#
# 潜在欺诈行为（'RES' = 1）：相比之下，这个类别中的指数分布似乎有更大的波动，尽管仍然大多数集中在0.9到1的区域。
#
# 数据分布情况：需要注意的是，'RES' = 1 的数据量相对较少（793条相对于15207条），这可能影响了分析的可靠性。这种数据不平衡的情况在实际的欺诈检测任务中很常见。
#
# 从可视化结果来看，虽然两个类别在个人账户使用异常指数上的分布有所不同，但区别并不十分显著。

# %% [markdown]
# ### 三目明细比例

# %%
columns_to_visualize_s = ['药品在总金额中的占比','检查总费用在总金额占比',
                          '个人支付检查费用占比','治疗费用在总金额占比',
                          '个人支付治疗费用占比',]

# Creating subplots for each feature
fig, axes = plt.subplots(nrows=len(columns_to_visualize_s), ncols=2, figsize=(12, 4*len(columns_to_visualize_s)), sharex='col')
bins = 30

# Plotting histograms for each feature
for i, col in enumerate(columns_to_visualize_s):
    # Histogram for fraudulent cases
    axes[i, 0].hist(data[col][data['RES'] == 1].values, bins=bins)
    axes[i, 0].set_title(f"欺诈 - {col}")
    axes[i, 0].set_ylabel("Distribution")
    axes[i, 0].set_yscale('log')

    # Histogram for non-fraudulent cases
    axes[i, 1].hist(data[col][data['RES'] == 0].values, bins=bins)
    axes[i, 1].set_title(f"非欺诈 - {col}")
    axes[i, 1].set_ylabel("Distribution")
    axes[i, 1].set_yscale('log')

# Setting common x-label
plt.xlabel("总计")
plt.tight_layout()
plt.show()

# %%
selected_features_s = ['药品在总金额中的占比','检查总费用在总金额占比',
                     '个人支付检查费用占比','治疗费用在总金额占比',
                     '个人支付治疗费用占比',
]

# Creating subplots for each selected feature
plt.figure(figsize=(12, len(selected_features_s) * 4))
gs = gridspec.GridSpec(len(selected_features_s), 1)
bins = 50

for i, feature in enumerate(selected_features_s):
    ax = plt.subplot(gs[i])
    sns.distplot(data[feature][data['RES'] == 1].values, bins=bins, label='Fraud', kde=False, norm_hist=True)
    sns.distplot(data[feature][data['RES'] == 0].values, bins=bins, label='Normal', kde=False, norm_hist=True)
    ax.set_xlabel('')
    ax.set_title(f'{feature}')
    ax.legend()

plt.show()

# %%
average_res_0 = data[data['RES'] == 0]['起付线标准金额_MAX'].mean()

# Counting the number of records in RES category 0 and 1 where '起付线标准金额_MAX' is above the average of RES category 0
count_above_avg_res_0 = data[(data['起付线标准金额_MAX'] > average_res_0) & (data['RES'] == 0)].shape[0]
count_above_avg_res_1 = data[(data['起付线标准金额_MAX'] > average_res_0) & (data['RES'] == 1)].shape[0]

average_res_0, count_above_avg_res_0, count_above_avg_res_1
# Out:
# (7.299927664891168, 84, 9)

# %%
features_to_analyze = [
    "起付标准以上自负比例金额_SUM", "医疗救助个人按比例负担金额_SUM", 
    "最高限额以上金额_SUM", "基本统筹基金支付金额_SUM"
]

# Dictionary to store the results
analysis_results = {}

# Calculating average values for each feature and counting the number of records exceeding the average for each RES category
for feature in features_to_analyze:
    average_res_0 = data[data['RES'] == 0][feature].mean()
    count_above_avg_res_0 = data[(data[feature] > average_res_0) & (data['RES'] == 0)].shape[0]
    count_above_avg_res_1 = data[(data[feature] > average_res_0) & (data['RES'] == 1)].shape[0]
    analysis_results[feature] = {
        "Average for RES Category 0": average_res_0,
        "Count above average in RES 0": count_above_avg_res_0,
        "Count above average in RES 1": count_above_avg_res_1
    }

analysis_results
# Out:
# {'起付标准以上自负比例金额_SUM': {'Average for RES Category 0': 2159.4594745840727,
#   'Count above average in RES 0': 4156,
#   'Count above average in RES 1': 462},
#  '医疗救助个人按比例负担金额_SUM': {'Average for RES Category 0': 31.889539028079177,
#   'Count above average in RES 0': 129,
#   'Count above average in RES 1': 147},
#  '最高限额以上金额_SUM': {'Average for RES Category 0': 0.08326297100019728,
#   'Count above average in RES 0': 1,
#   'Count above average in RES 1': 0},
#  '基本统筹基金支付金额_SUM': {'Average for RES Category 0': 14931.06116393766,
#   'Count above average in RES 0': 5559,
#   'Count above average in RES 1': 450}}

# %%
iqr_values = {}
for feature in features_to_analyze:
    q1 = data[data['RES'] == 0][feature].quantile(0.25)
    q3 = data[data['RES'] == 0][feature].quantile(0.75)
    iqr = q3 - q1
    iqr_values[feature] = {'Q1': q1, 'Q3': q3, 'IQR': iqr, 'Upper Bound': q3 + 1.5 * iqr}

# Counting the number of entries in RES category 0 and 1 that are above the upper bound (outliers) for each feature
outlier_counts = {}
for feature in features_to_analyze:
    upper_bound = iqr_values[feature]['Upper Bound']
    count_res_0_outliers = data[(data[feature] > upper_bound) & (data['RES'] == 0)].shape[0]
    count_res_1_outliers = data[(data[feature] > upper_bound) & (data['RES'] == 1)].shape[0]
    outlier_counts[feature] = {'Count in RES 0': count_res_0_outliers, 'Count in RES 1': count_res_1_outliers}

outlier_counts
# Out:
# {'起付标准以上自负比例金额_SUM': {'Count in RES 0': 1548, 'Count in RES 1': 358},
#  '医疗救助个人按比例负担金额_SUM': {'Count in RES 0': 130, 'Count in RES 1': 148},
#  '最高限额以上金额_SUM': {'Count in RES 0': 1, 'Count in RES 1': 0},
#  '基本统筹基金支付金额_SUM': {'Count in RES 0': 957, 'Count in RES 1': 312}}

# %% [markdown]
# ## 出院诊断统计

# %%
df['医院编码_NN'].value_counts()
# Out:
# 医院编码_NN
# 2    6343
# 1    4389
# 3    3607
# 4    1211
# 5     329
# 6      83
# 7      30
# 8       5
# 9       3
# Name: count, dtype: int64

# %%
df['出院诊断病种名称_NN'].value_counts()
# Out:
# 出院诊断病种名称_NN
# 4     2683
# 5     2669
# 3     2063
# 6     1979
# 2     1742
# 7     1552
# 8      984
# 9      656
# 10     449
# 0      355
# 11     283
# 12     180
# 13     132
# 14      64
# 1       50
# 15      49
# 16      32
# 17      30
# 19      12
# 18      10
# 22       5
# 20       4
# 23       3
# 24       3
# 32       3
# 21       3
# 25       2
# 39       1
# 34       1
# 28       1
# Name: count, dtype: int64

# %%
df['出院诊断LENTH_MAX'].value_counts()
# Out:
# 出院诊断LENTH_MAX
# 22.0    669
# 30.0    584
# 21.0    557
# 26.0    533
# 20.0    525
# 28.0    500
# 25.0    492
# 29.0    466
# 32.0    465
# 24.0    465
# 34.0    454
# 27.0    446
# 17.0    436
# 16.0    427
# 31.0    421
# 23.0    405
# 19.0    399
# 38.0    383
# 13.0    358
# 0.0     355
# 15.0    351
# 18.0    335
# 33.0    332
# 35.0    327
# 14.0    304
# 37.0    291
# 36.0    287
# 10.0    282
# 11.0    273
# 12.0    241
# 42.0    241
# 4.0     230
# 40.0    223
# 41.0    211
# 5.0     200
# 7.0     179
# 3.0     166
# 9.0     162
# 45.0    159
# 39.0    154
# 44.0    144
# 8.0     142
# 6.0     133
# 2.0     128
# 43.0    119
# 47.0    111
# 46.0    109
# 49.0    107
# 50.0     95
# 52.0     91
# 48.0     84
# 51.0     59
# 53.0     49
# 54.0     47
# 58.0     45
# 56.0     33
# 55.0     33
# 57.0     31
# 59.0     24
# 70.0     21
# 60.0     19
# 61.0     16
# 63.0     14
# 62.0     13
# 66.0     12
# 64.0      9
# 65.0      9
# 67.0      6
# 69.0      4
# 68.0      3
# 86.0      1
# 76.0      1
# Name: count, dtype: int64

# %%
# 类别为1的数目统计

category_1_data = df[df['RES'] == 1]

# Calculate the frequency for each of the specified columns
hospital_code_freq = category_1_data['医院编码_NN'].value_counts().sort_index()
diagnosis_name_freq = category_1_data['出院诊断病种名称_NN'].value_counts().sort_index()
diagnosis_length_freq = category_1_data['出院诊断LENTH_MAX'].value_counts().sort_index()

hospital_code_freq, diagnosis_name_freq, diagnosis_length_freq
# Out:
# (医院编码_NN
#  1    167
#  2    209
#  3    222
#  4    124
#  5     36
#  6     19
#  7     13
#  8      1
#  9      2
#  Name: count, dtype: int64,
#  出院诊断病种名称_NN
#  0      28
#  1       3
#  2      68
#  3      78
#  4      86
#  5     100
#  6      59
#  7      70
#  8      48
#  9      30
#  10     49
#  11     35
#  12     29
#  13     17
#  14     15
#  15     22
#  16      9
#  17     16
#  18      5
#  19      6
#  20      2
#  21      3
#  22      4
#  23      3
#  25      2
#  28      1
#  32      3
#  34      1
#  39      1
#  Name: count, dtype: int64,
#  出院诊断LENTH_MAX
#  0.0     28
#  2.0     12
#  3.0      4
#  4.0     10
#  5.0      9
#  6.0      5
#  7.0      4
#  8.0      9
#  9.0      5
#  10.0     6
#  11.0    12
#  12.0    13
#  13.0    11
#  14.0     6
#  15.0    14
#  16.0    18
#  17.0    18
#  18.0    11
#  19.0    12
#  20.0    21
#  21.0    20
#  22.0    73
#  23.0    11
#  24.0    28
#  25.0    35
#  26.0    25
#  27.0    26
#  28.0    19
#  29.0    24
#  30.0    21
#  31.0    17
#  32.0    12
#  33.0    14
#  34.0    29
#  35.0    26
#  36.0     8
#  37.0     9
#  38.0    39
#  39.0    12
#  40.0    14
#  41.0    10
#  42.0    16
#  43.0     2
#  44.0     8
#  45.0     2
#  46.0     6
#  47.0     3
#  48.0     3
#  49.0     3
#  50.0     2
#  51.0     1
#  52.0    24
#  53.0     4
#  54.0     2
#  55.0     3
#  56.0     4
#  57.0     1
#  58.0     4
#  59.0     1
#  61.0     2
#  66.0     1
#  70.0     1
#  Name: count, dtype: int64)

# %% [markdown]
# ## 0值占比

# %%
# 比例为0的特征不显示
# 分别为欺诈（RES=1）和非欺诈（RES=0）的数据集计算每个特征值为0的数量
fraud_zero_counts = (data[data['RES'] == 1] == 0).sum()
non_fraud_zero_counts = (data[data['RES'] == 0] == 0).sum()

# 计算每个特征值为0的比例
fraud_zero_proportions = fraud_zero_counts / len(data[data['RES'] == 1])
non_fraud_zero_proportions = non_fraud_zero_counts / len(data[data['RES'] == 0])

# 创建两个新的数据框，用于可视化
fraud_zero_proportions_df = pd.DataFrame({'Feature': fraud_zero_proportions.index, 'Zero Proportion': fraud_zero_proportions.values})
non_fraud_zero_proportions_df = pd.DataFrame({'Feature': non_fraud_zero_proportions.index, 'Zero Proportion': non_fraud_zero_proportions.values})

# 过滤掉比例为0的特征
fraud_zero_proportions_df = fraud_zero_proportions_df[fraud_zero_proportions_df['Zero Proportion'] > 0]
non_fraud_zero_proportions_df = non_fraud_zero_proportions_df[non_fraud_zero_proportions_df['Zero Proportion'] > 0]

# %%
# 对欺诈数据的零比例进行降序排序
fraud_zero_proportions_df_sorted = fraud_zero_proportions_df.sort_values(by='Zero Proportion', ascending=False)
fraud_zero_proportions_df_sorted.head(10)
# Out:
#          Feature  Zero Proportion
# 57  最高限额以上金额_SUM         1.000000
# 24      住院天数_SUM         1.000000
# 68    城乡优抚补助_SUM         0.998739
# 50  成分输血申报金额_SUM         0.998739
# 78       BZ_城乡优抚         0.998739
# 66    残疾军人补助_SUM         0.998739
# 52    其它申报金额_SUM         0.997478
# 43   手术费自费金额_SUM         0.996217
# 44   手术费申报金额_SUM         0.993695
# 42   手术费发生金额_SUM         0.991173

# %%
non_fraud_zero_proportions_df.sort_values(by='Zero Proportion', ascending=False).head(15)
# Out:
#               Feature  Zero Proportion
# 80                RES         1.000000
# 24           住院天数_SUM         1.000000
# 57       最高限额以上金额_SUM         0.999934
# 66         残疾军人补助_SUM         0.999671
# 78            BZ_城乡优抚         0.999474
# 68         城乡优抚补助_SUM         0.999474
# 52         其它申报金额_SUM         0.999408
# 43        手术费自费金额_SUM         0.999014
# 50       成分输血申报金额_SUM         0.998948
# 48       高价材料发生金额_SUM         0.995594
# 54        起付线标准金额_MAX         0.994476
# 44        手术费申报金额_SUM         0.994279
# 42        手术费发生金额_SUM         0.993556
# 65       医疗救助医院申请_SUM         0.991451
# 56  医疗救助个人按比例负担金额_SUM         0.991451

# %%
data[['住院天数_SUM']].describe()
# Out:
#        住院天数_SUM
# count   16000.0
# mean        0.0
# std         0.0
# min         0.0
# 25%         0.0
# 50%         0.0
# 75%         0.0
# max         0.0

# %%
# Calculate the correlation matrix
treatment_corr = data[['治疗费发生金额_SUM', '治疗费自费金额_SUM', '治疗费申报金额_SUM']].corr()

# Plot the heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(treatment_corr, annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap of Treatment Costs')
plt.show()

# %% [markdown]
# ## 费用特征探索

# %%
# 统计药品费自费金额_SUM和药品费申报金额_SUM的总和小于药品费发生金额_SUM的记录数
count = data[(data['药品费自费金额_SUM'] + data['药品费申报金额_SUM']) < data['药品费发生金额_SUM']].shape[0]

print("满足条件的记录数：", count)
# Out:
# 满足条件的记录数： 11098

# %%
# 筛选出类别1的样本
class_1_data = data[data['RES'] == 1]

# 统计满足条件的个数
count = class_1_data[(class_1_data['药品费自费金额_SUM'] + class_1_data['药品费申报金额_SUM']) < class_1_data['药品费发生金额_SUM']].shape[0]

print("满足条件的样本个数：", count)
# Out:
# 满足条件的样本个数： 670

# %%
# 设置图表样式
# sns.set(style="whitegrid")

# 指定特征列表
features = ['药品在总金额中的占比', '检查总费用在总金额占比', '个人支付检查费用占比', '治疗费用在总金额占比', '个人支付治疗费用占比']

# 为每个特征分别绘制两个类别的分布图
for feature in features:
    plt.figure(figsize=(10, 6))
    sns.histplot(data[data['RES'] == 0][feature], color='blue', kde=True, label='Class 0')
    sns.histplot(data[data['RES'] == 1][feature], color='red', kde=True, label='Class 1')
    plt.title(f'Distribution of {feature} for Both Classes')
    plt.xlabel(feature)
    plt.ylabel('Count')
    plt.legend()
    plt.show()

# %%
# 筛选类别为 0 的数据
data_class_0 = data[data['RES'] == 0]

# 计算类别 0 中每个病种的平均费用
average_costs_class_0 = data_class_0.groupby('出院诊断病种名称_NN').mean()[['药品费发生金额_SUM', '贵重药品发生金额_SUM', '检查费发生金额_SUM']]

# 可视化类别 0 中不同病种的平均药品费用
plt.figure(figsize=(10, 6))
sns.barplot(x=average_costs_class_0.index, y="药品费发生金额_SUM", data=average_costs_class_0)
plt.xticks(rotation=45)
plt.title('Average Drug Cost by Disease for Class 0')
plt.show()

# 筛选类别为 1 的数据
data_class_1 = data[data['RES'] == 1]

# 计算类别 1 中每个病种的平均费用
average_costs_class_1 = data_class_1.groupby('出院诊断病种名称_NN').mean()[['药品费发生金额_SUM', '贵重药品发生金额_SUM', '检查费发生金额_SUM']]

# 获取在两个类别中都存在的病种
common_diseases = set(data_class_0['出院诊断病种名称_NN']).intersection(set(data_class_1['出院诊断病种名称_NN']))

# 将 set 转换为 list 以用于索引
common_diseases_list = list(common_diseases)

# 只考虑这些病种
average_costs_class_0_common = average_costs_class_0.loc[common_diseases_list]
average_costs_class_1_common = average_costs_class_1.loc[common_diseases_list]

# 统计类别 1 中超过类别 0 平均值的病种数量
count_above_average = {}
for column in ['药品费发生金额_SUM', '贵重药品发生金额_SUM', '检查费发生金额_SUM']:
    count_above_average[column] = (average_costs_class_1_common[column] > average_costs_class_0_common[column].mean()).sum()

count_above_average
# Out:
# {'药品费发生金额_SUM': 16, '贵重药品发生金额_SUM': 19, '检查费发生金额_SUM': 17}

# %%
claim_payment_features = [
    "药品费申报金额_SUM", "检查费申报金额_SUM", "治疗费申报金额_SUM",
    "手术费申报金额_SUM", "床位费申报金额_SUM", "其它申报金额_SUM"
]
total_payment_features = [
    "药品费发生金额_SUM", "检查费发生金额_SUM", "治疗费发生金额_SUM",
    "手术费发生金额_SUM", "床位费发生金额_SUM", "其它发生金额_SUM"
]

# Calculating the proportion of claim payment to the total payment for each sample
for claim_feature, total_feature in zip(claim_payment_features, total_payment_features):
    data[f'{claim_feature}_占比'] = data[claim_feature] / data[total_feature]
    data[f'{claim_feature}_占比'] = data[f'{claim_feature}_占比'].fillna(0)
    # Handling cases where the total payment is zero
    data[f'{claim_feature}_占比'] = data[f'{claim_feature}_占比'].replace([float('inf'), -float('inf')], 0)

# Optional: Save the result to a new CSV file
data.to_csv('updated_dataset.csv', index=False)

# %%
# Counting the number of records where total payment is 0, but self-payment and claim payment are not 0
non_zero_counts = {}
for total_feature, claim_feature in zip(total_payment_features, claim_payment_features):
    count_non_zero_claim = data[(data[total_feature] == 0) & (data[claim_feature] != 0)].shape[0]
    non_zero_counts[total_feature] = {
        "Non-Zero Claim Count": count_non_zero_claim
    }

non_zero_counts
# Out:
# {'药品费发生金额_SUM': {'Non-Zero Claim Count': 0},
#  '检查费发生金额_SUM': {'Non-Zero Claim Count': 0},
#  '治疗费发生金额_SUM': {'Non-Zero Claim Count': 0},
#  '手术费发生金额_SUM': {'Non-Zero Claim Count': 0},
#  '床位费发生金额_SUM': {'Non-Zero Claim Count': 0},
#  '其它发生金额_SUM': {'Non-Zero Claim Count': 0}}

# %%
# Features to analyze
features_to_analyze = [
    "个人账户金额_SUM", "统筹支付金额_SUM", "ALL_SUM", "可用账户报销金额_SUM", 
    "药品费发生金额_SUM", "药品费自费金额_SUM", "药品费申报金额_SUM", "贵重药品发生金额_SUM",
    "中成药费发生金额_SUM", "中草药费发生金额_SUM", "检查费发生金额_SUM", "检查费自费金额_SUM",
    "检查费申报金额_SUM", "贵重检查费金额_SUM", "治疗费发生金额_SUM", "治疗费自费金额_SUM",
    "治疗费申报金额_SUM", "手术费发生金额_SUM", "手术费自费金额_SUM", "手术费申报金额_SUM",
    "床位费发生金额_SUM", "床位费申报金额_SUM", "医用材料发生金额_SUM", "高价材料发生金额_SUM",
    "医用材料费自费金额_SUM", "成分输血申报金额_SUM", "其它发生金额_SUM", "其它申报金额_SUM",
    "一次性医用材料申报金额_SUM", "起付线标准金额_MAX", "起付标准以上自负比例金额_SUM", "医疗救助个人按比例负担金额_SUM",
    "最高限额以上金额_SUM", "基本统筹基金支付金额_SUM", "公务员医疗补助基金支付金额_SUM", "城乡救助补助金额_SUM",
    "基本个人账户支付_SUM", "非账户支付金额_SUM", "本次审批金额_SUM", "补助审批金额_SUM", 
    "医疗救助医院申请_SUM", "残疾军人补助_SUM", "民政救助补助_SUM", "城乡优抚补助_SUM", 
    "药品在总金额中的占比", "个人支付的药品占比", "检查总费用在总金额占比", "个人支付检查费用占比",
    "治疗费用在总金额占比", "个人支付治疗费用占比", "BZ_民政救助", "BZ_城乡优抚"
]

# Disease category feature
disease_feature = "出院诊断病种名称_NN"

# Calculating average values for each feature for each disease in RES category 0
disease_averages = data[data['RES'] == 0].groupby(disease_feature)[features_to_analyze].mean()

# Initializing a dictionary to store the counts of records exceeding the average for each disease in each RES category
exceeding_average_counts = {disease: {} for disease in disease_averages.index}

# Counting the number of records in each disease category in RES category 0 and 1 that exceed the average of RES category 0
for disease in disease_averages.index:
    for feature in features_to_analyze:
        average_value = disease_averages.loc[disease, feature]
        count_res_0_exceeding = data[(data[disease_feature] == disease) & (data['RES'] == 0) & (data[feature] > average_value)].shape[0]
        count_res_1_exceeding = data[(data[disease_feature] == disease) & (data['RES'] == 1) & (data[feature] > average_value)].shape[0]
        exceeding_average_counts[disease][feature] = {"RES 0": count_res_0_exceeding, "RES 1": count_res_1_exceeding}

# Since the output might be large, showing the result for the first few diseases as a sample
list(exceeding_average_counts.items())[:5]
# Out:
# [(0,
#   {'个人账户金额_SUM': {'RES 0': 103, 'RES 1': 13},
#    '统筹支付金额_SUM': {'RES 0': 125, 'RES 1': 18},
#    'ALL_SUM': {'RES 0': 128, 'RES 1': 17},
#    '可用账户报销金额_SUM': {'RES 0': 100, 'RES 1': 13},
#    '药品费发生金额_SUM': {'RES 0': 130, 'RES 1': 16},
#    '药品费自费金额_SUM': {'RES 0': 47, 'RES 1': 8},
#    '药品费申报金额_SUM': {'RES 0': 132, 'RES 1': 16},
#    '贵重药品发生金额_SUM': {'RES 0': 67, 'RES 1': 8},
#    '中成药费发生金额_SUM': {'RES 0': 90, 'RES 1': 13},
#    '中草药费发生金额_SUM': {'RES 0': 94, 'RES 1': 10},
#    '检查费发生金额_SUM': {'RES 0': 91, 'RES 1': 12},
#    '检查费自费金额_SUM': {'RES 0': 32, 'RES 1': 6},
#    '检查费申报金额_SUM': {'RES 0': 98, 'RES 1': 12},
#    '贵重检查费金额_SUM': {'RES 0': 65, 'RES 1': 9},
#    '治疗费发生金额_SUM': {'RES 0': 42, 'RES 1': 9},
#    '治疗费自费金额_SUM': {'RES 0': 26, 'RES 1': 4},
#    '治疗费申报金额_SUM': {'RES 0': 42, 'RES 1': 9},
#    '手术费发生金额_SUM': {'RES 0': 3, 'RES 1': 0},
#    '手术费自费金额_SUM': {'RES 0': 0, 'RES 1': 0},
#    '手术费申报金额_SUM': {'RES 0': 3, 'RES 1': 0},
#    '床位费发生金额_SUM': {'RES 0': 16, 'RES 1': 6},
#    '床位费申报金额_SUM': {'RES 0': 16, 'RES 1': 6},
#    '医用材料发生金额_SUM': {'RES 0': 113, 'RES 1': 12},
#    '高价材料发生金额_SUM': {'RES 0': 10, 'RES 1': 4},
#    '医用材料费自费金额_SUM': {'RES 0': 33, 'RES 1': 7},
#    '成分输血申报金额_SUM': {'RES 0': 1, 'RES 1': 0},
#    '其它发生金额_SUM': {'RES 0': 31, 'RES 1': 7},
#    '其它申报金额_SUM': {'RES 0': 0, 'RES 1': 0},
#    '一次性医用材料申报金额_SUM': {'RES 0': 108, 'RES 1': 7},
#    '起付线标准金额_MAX': {'RES 0': 12, 'RES 1': 4},
#    '起付标准以上自负比例金额_SUM': {'RES 0': 104, 'RES 1': 16},
#    '医疗救助个人按比例负担金额_SUM': {'RES 0': 10, 'RES 1': 0},
#    '最高限额以上金额_SUM': {'RES 0': 0, 'RES 1': 0},
#    '基本统筹基金支付金额_SUM': {'RES 0': 128, 'RES 1': 18},
#    '公务员医疗补助基金支付金额_SUM': {'RES 0': 6, 'RES 1': 0},
#    '城乡救助补助金额_SUM': {'RES 0': 22, 'RES 1': 3},
#    '基本个人账户支付_SUM': {'RES 0': 91, 'RES 1': 11},
#    '非账户支付金额_SUM': {'RES 0': 101, 'RES 1': 13},
#    '本次审批金额_SUM': {'RES 0': 126, 'RES 1': 17},
#    '补助审批金额_SUM': {'RES 0': 22, 'RES 1': 3},
#    '医疗救助医院申请_SUM': {'RES 0': 10, 'RES 1': 0},
#    '残疾军人补助_SUM': {'RES 0': 0, 'RES 1': 0},
#    '民政救助补助_SUM': {'RES 0': 22, 'RES 1': 3},
#    '城乡优抚补助_SUM': {'RES 0': 0, 'RES 1': 0},
#    '药品在总金额中的占比': {'RES 0': 215, 'RES 1': 18},
#    '个人支付的药品占比': {'RES 0': 50, 'RES 1': 8},
#    '检查总费用在总金额占比': {'RES 0': 85, 'RES 1': 4},
#    '个人支付检查费用占比': {'RES 0': 43, 'RES 1': 7},
#    '治疗费用在总金额占比': {'RES 0': 54, 'RES 1': 8},
#    '个人支付治疗费用占比': {'RES 0': 28, 'RES 1': 3},
#    'BZ_民政救助': {'RES 0': 26, 'RES 1': 3},
#    'BZ_城乡优抚': {'RES 0': 0, 'RES 1': 0}}),
#  (1,
#   {'个人账户金额_SUM': {'RES 0': 13, 'RES 1': 1},
#    '统筹支付金额_SUM': {'RES 0': 14, 'RES 1': 1},
#    'ALL_SUM': {'RES 0': 17, 'RES 1': 1},
#    '可用账户报销金额_SUM': {'RES 0': 14, 'RES 1': 1},
#    '药品费发生金额_SUM': {'RES 0': 25, 'RES 1': 0},
#    '药品费自费金额_SUM': {'RES 0': 6, 'RES 1': 2},
#    '药品费申报金额_SUM': {'RES 0': 23, 'RES 1': 0},
#    '贵重药品发生金额_SUM': {'RES 0': 20, 'RES 1': 0},
#    '中成药费发生金额_SUM': {'RES 0': 13, 'RES 1': 0},
#    '中草药费发生金额_SUM': {'RES 0': 12, 'RES 1': 1},
#    '检查费发生金额_SUM': {'RES 0': 11, 'RES 1': 1},
#    '检查费自费金额_SUM': {'RES 0': 4, 'RES 1': 0},
#    '检查费申报金额_SUM': {'RES 0': 12, 'RES 1': 1},
#    '贵重检查费金额_SUM': {'RES 0': 11, 'RES 1': 0},
#    '治疗费发生金额_SUM': {'RES 0': 5, 'RES 1': 2},
#    '治疗费自费金额_SUM': {'RES 0': 5, 'RES 1': 0},
#    '治疗费申报金额_SUM': {'RES 0': 5, 'RES 1': 2},
#    '手术费发生金额_SUM': {'RES 0': 1, 'RES 1': 0},
#    '手术费自费金额_SUM': {'RES 0': 0, 'RES 1': 0},
#    '手术费申报金额_SUM': {'RES 0': 1, 'RES 1': 0},
#    '床位费发生金额_SUM': {'RES 0': 2, 'RES 1': 0},
#    '床位费申报金额_SUM': {'RES 0': 2, 'RES 1': 0},
#    '医用材料发生金额_SUM': {'RES 0': 12, 'RES 1': 1},
#    '高价材料发生金额_SUM': {'RES 0': 0, 'RES 1': 0},
#    '医用材料费自费金额_SUM': {'RES 0': 8, 'RES 1': 1},
#    '成分输血申报金额_SUM': {'RES 0': 3, 'RES 1': 0},
#    '其它发生金额_SUM': {'RES 0': 4, 'RES 1': 0},
#    '其它申报金额_SUM': {'RES 0': 0, 'RES 1': 0},
#    '一次性医用材料申报金额_SUM': {'RES 0': 12, 'RES 1': 1},
#    '起付线标准金额_MAX': {'RES 0': 0, 'RES 1': 0},
#    '起付标准以上自负比例金额_SUM': {'RES 0': 12, 'RES 1': 1},
#    '医疗救助个人按比例负担金额_SUM': {'RES 0': 1, 'RES 1': 0},
#    '最高限额以上金额_SUM': {'RES 0': 0, 'RES 1': 0},
#    '基本统筹基金支付金额_SUM': {'RES 0': 18, 'RES 1': 1},
#    '公务员医疗补助基金支付金额_SUM': {'RES 0': 0, 'RES 1': 0},
#    '城乡救助补助金额_SUM': {'RES 0': 5, 'RES 1': 0},
#    '基本个人账户支付_SUM': {'RES 0': 16, 'RES 1': 0},
#    '非账户支付金额_SUM': {'RES 0': 15, 'RES 1': 1},
#    '本次审批金额_SUM': {'RES 0': 17, 'RES 1': 1},
#    '补助审批金额_SUM': {'RES 0': 5, 'RES 1': 0},
#    '医疗救助医院申请_SUM': {'RES 0': 1, 'RES 1': 0},
#    '残疾军人补助_SUM': {'RES 0': 0, 'RES 1': 0},
#    '民政救助补助_SUM': {'RES 0': 5, 'RES 1': 0},
#    '城乡优抚补助_SUM': {'RES 0': 0, 'RES 1': 0},
#    '药品在总金额中的占比': {'RES 0': 31, 'RES 1': 1},
#    '个人支付的药品占比': {'RES 0': 3, 'RES 1': 2},
#    '检查总费用在总金额占比': {'RES 0': 14, 'RES 1': 1},
#    '个人支付检查费用占比': {'RES 0': 4, 'RES 1': 0},
#    '治疗费用在总金额占比': {'RES 0': 8, 'RES 1': 2},
#    '个人支付治疗费用占比': {'RES 0': 5, 'RES 1': 0},
#    'BZ_民政救助': {'RES 0': 5, 'RES 1': 0},
#    'BZ_城乡优抚': {'RES 0': 0, 'RES 1': 0}}),
#  (2,
#   {'个人账户金额_SUM': {'RES 0': 527, 'RES 1': 19},
#    '统筹支付金额_SUM': {'RES 0': 622, 'RES 1': 18},
#    'ALL_SUM': {'RES 0': 602, 'RES 1': 18},
#    '可用账户报销金额_SUM': {'RES 0': 525, 'RES 1': 19},
#    '药品费发生金额_SUM': {'RES 0': 694, 'RES 1': 14},
#    '药品费自费金额_SUM': {'RES 0': 251, 'RES 1': 8},
#    '药品费申报金额_SUM': {'RES 0': 697, 'RES 1': 14},
#    '贵重药品发生金额_SUM': {'RES 0': 442, 'RES 1': 12},
#    '中成药费发生金额_SUM': {'RES 0': 619, 'RES 1': 25},
#    '中草药费发生金额_SUM': {'RES 0': 503, 'RES 1': 10},
#    '检查费发生金额_SUM': {'RES 0': 515, 'RES 1': 22},
#    '检查费自费金额_SUM': {'RES 0': 157, 'RES 1': 7},
#    '检查费申报金额_SUM': {'RES 0': 522, 'RES 1': 21},
#    '贵重检查费金额_SUM': {'RES 0': 239, 'RES 1': 11},
#    '治疗费发生金额_SUM': {'RES 0': 217, 'RES 1': 18},
#    '治疗费自费金额_SUM': {'RES 0': 131, 'RES 1': 2},
#    '治疗费申报金额_SUM': {'RES 0': 215, 'RES 1': 18},
#    '手术费发生金额_SUM': {'RES 0': 23, 'RES 1': 0},
#    '手术费自费金额_SUM': {'RES 0': 3, 'RES 1': 1},
#    '手术费申报金额_SUM': {'RES 0': 22, 'RES 1': 0},
#    '床位费发生金额_SUM': {'RES 0': 71, 'RES 1': 2},
#    '床位费申报金额_SUM': {'RES 0': 69, 'RES 1': 2},
#    '医用材料发生金额_SUM': {'RES 0': 574, 'RES 1': 21},
#    '高价材料发生金额_SUM': {'RES 0': 10, 'RES 1': 1},
#    '医用材料费自费金额_SUM': {'RES 0': 209, 'RES 1': 7},
#    '成分输血申报金额_SUM': {'RES 0': 8, 'RES 1': 0},
#    '其它发生金额_SUM': {'RES 0': 217, 'RES 1': 5},
#    '其它申报金额_SUM': {'RES 0': 0, 'RES 1': 0},
#    '一次性医用材料申报金额_SUM': {'RES 0': 562, 'RES 1': 23},
#    '起付线标准金额_MAX': {'RES 0': 7, 'RES 1': 0},
#    '起付标准以上自负比例金额_SUM': {'RES 0': 486, 'RES 1': 19},
#    '医疗救助个人按比例负担金额_SUM': {'RES 0': 16, 'RES 1': 2},
#    '最高限额以上金额_SUM': {'RES 0': 1, 'RES 1': 0},
#    '基本统筹基金支付金额_SUM': {'RES 0': 660, 'RES 1': 19},
#    '公务员医疗补助基金支付金额_SUM': {'RES 0': 45, 'RES 1': 2},
#    '城乡救助补助金额_SUM': {'RES 0': 173, 'RES 1': 9},
#    '基本个人账户支付_SUM': {'RES 0': 613, 'RES 1': 26},
#    '非账户支付金额_SUM': {'RES 0': 508, 'RES 1': 20},
#    '本次审批金额_SUM': {'RES 0': 612, 'RES 1': 18},
#    '补助审批金额_SUM': {'RES 0': 174, 'RES 1': 9},
#    '医疗救助医院申请_SUM': {'RES 0': 16, 'RES 1': 2},
#    '残疾军人补助_SUM': {'RES 0': 1, 'RES 1': 0},
#    '民政救助补助_SUM': {'RES 0': 172, 'RES 1': 9},
#    '城乡优抚补助_SUM': {'RES 0': 1, 'RES 1': 0},
#    '药品在总金额中的占比': {'RES 0': 1197, 'RES 1': 38},
#    '个人支付的药品占比': {'RES 0': 263, 'RES 1': 11},
#    '检查总费用在总金额占比': {'RES 0': 492, 'RES 1': 22},
#    '个人支付检查费用占比': {'RES 0': 165, 'RES 1': 9},
#    '治疗费用在总金额占比': {'RES 0': 296, 'RES 1': 23},
#    '个人支付治疗费用占比': {'RES 0': 168, 'RES 1': 2},
#    'BZ_民政救助': {'RES 0': 180, 'RES 1': 9},
#    'BZ_城乡优抚': {'RES 0': 1, 'RES 1': 0}}),
#  (3,
#   {'个人账户金额_SUM': {'RES 0': 539, 'RES 1': 25},
#    '统筹支付金额_SUM': {'RES 0': 630, 'RES 1': 21},
#    'ALL_SUM': {'RES 0': 611, 'RES 1': 23},
#    '可用账户报销金额_SUM': {'RES 0': 506, 'RES 1': 26},
#    '药品费发生金额_SUM': {'RES 0': 674, 'RES 1': 20},
#    '药品费自费金额_SUM': {'RES 0': 387, 'RES 1': 13},
#    '药品费申报金额_SUM': {'RES 0': 683, 'RES 1': 20},
#    '贵重药品发生金额_SUM': {'RES 0': 427, 'RES 1': 16},
#    '中成药费发生金额_SUM': {'RES 0': 760, 'RES 1': 26},
#    '中草药费发生金额_SUM': {'RES 0': 738, 'RES 1': 13},
#    '检查费发生金额_SUM': {'RES 0': 652, 'RES 1': 19},
#    '检查费自费金额_SUM': {'RES 0': 158, 'RES 1': 6},
#    '检查费申报金额_SUM': {'RES 0': 666, 'RES 1': 19},
#    '贵重检查费金额_SUM': {'RES 0': 205, 'RES 1': 6},
#    '治疗费发生金额_SUM': {'RES 0': 271, 'RES 1': 22},
#    '治疗费自费金额_SUM': {'RES 0': 138, 'RES 1': 2},
#    '治疗费申报金额_SUM': {'RES 0': 273, 'RES 1': 22},
#    '手术费发生金额_SUM': {'RES 0': 23, 'RES 1': 1},
#    '手术费自费金额_SUM': {'RES 0': 1, 'RES 1': 0},
#    '手术费申报金额_SUM': {'RES 0': 22, 'RES 1': 1},
#    '床位费发生金额_SUM': {'RES 0': 91, 'RES 1': 2},
#    '床位费申报金额_SUM': {'RES 0': 85, 'RES 1': 2},
#    '医用材料发生金额_SUM': {'RES 0': 632, 'RES 1': 18},
#    '高价材料发生金额_SUM': {'RES 0': 11, 'RES 1': 2},
#    '医用材料费自费金额_SUM': {'RES 0': 293, 'RES 1': 7},
#    '成分输血申报金额_SUM': {'RES 0': 3, 'RES 1': 0},
#    '其它发生金额_SUM': {'RES 0': 337, 'RES 1': 6},
#    '其它申报金额_SUM': {'RES 0': 3, 'RES 1': 0},
#    '一次性医用材料申报金额_SUM': {'RES 0': 611, 'RES 1': 18},
#    '起付线标准金额_MAX': {'RES 0': 14, 'RES 1': 2},
#    '起付标准以上自负比例金额_SUM': {'RES 0': 459, 'RES 1': 27},
#    '医疗救助个人按比例负担金额_SUM': {'RES 0': 26, 'RES 1': 4},
#    '最高限额以上金额_SUM': {'RES 0': 0, 'RES 1': 0},
#    '基本统筹基金支付金额_SUM': {'RES 0': 650, 'RES 1': 23},
#    '公务员医疗补助基金支付金额_SUM': {'RES 0': 61, 'RES 1': 2},
#    '城乡救助补助金额_SUM': {'RES 0': 259, 'RES 1': 15},
#    '基本个人账户支付_SUM': {'RES 0': 826, 'RES 1': 15},
#    '非账户支付金额_SUM': {'RES 0': 534, 'RES 1': 26},
#    '本次审批金额_SUM': {'RES 0': 618, 'RES 1': 23},
#    '补助审批金额_SUM': {'RES 0': 262, 'RES 1': 15},
#    '医疗救助医院申请_SUM': {'RES 0': 26, 'RES 1': 4},
#    '残疾军人补助_SUM': {'RES 0': 2, 'RES 1': 0},
#    '民政救助补助_SUM': {'RES 0': 256, 'RES 1': 15},
#    '城乡优抚补助_SUM': {'RES 0': 3, 'RES 1': 0},
#    '药品在总金额中的占比': {'RES 0': 1408, 'RES 1': 45},
#    '个人支付的药品占比': {'RES 0': 405, 'RES 1': 11},
#    '检查总费用在总金额占比': {'RES 0': 616, 'RES 1': 20},
#    '个人支付检查费用占比': {'RES 0': 188, 'RES 1': 6},
#    '治疗费用在总金额占比': {'RES 0': 326, 'RES 1': 27},
#    '个人支付治疗费用占比': {'RES 0': 167, 'RES 1': 2},
#    'BZ_民政救助': {'RES 0': 265, 'RES 1': 15},
#    'BZ_城乡优抚': {'RES 0': 3, 'RES 1': 0}}),
#  (4,
#   {'个人账户金额_SUM': {'RES 0': 773, 'RES 1': 35},
#    '统筹支付金额_SUM': {'RES 0': 891, 'RES 1': 32},
#    'ALL_SUM': {'RES 0': 858, 'RES 1': 32},
#    '可用账户报销金额_SUM': {'RES 0': 752, 'RES 1': 34},
#    '药品费发生金额_SUM': {'RES 0': 1010, 'RES 1': 25},
#    '药品费自费金额_SUM': {'RES 0': 580, 'RES 1': 22},
#    '药品费申报金额_SUM': {'RES 0': 1013, 'RES 1': 26},
#    '贵重药品发生金额_SUM': {'RES 0': 819, 'RES 1': 32},
#    '中成药费发生金额_SUM': {'RES 0': 997, 'RES 1': 29},
#    '中草药费发生金额_SUM': {'RES 0': 984, 'RES 1': 7},
#    '检查费发生金额_SUM': {'RES 0': 822, 'RES 1': 23},
#    '检查费自费金额_SUM': {'RES 0': 184, 'RES 1': 8},
#    '检查费申报金额_SUM': {'RES 0': 839, 'RES 1': 24},
#    '贵重检查费金额_SUM': {'RES 0': 195, 'RES 1': 9},
#    '治疗费发生金额_SUM': {'RES 0': 357, 'RES 1': 29},
#    '治疗费自费金额_SUM': {'RES 0': 240, 'RES 1': 8},
#    '治疗费申报金额_SUM': {'RES 0': 357, 'RES 1': 29},
#    '手术费发生金额_SUM': {'RES 0': 17, 'RES 1': 0},
#    '手术费自费金额_SUM': {'RES 0': 6, 'RES 1': 0},
#    '手术费申报金额_SUM': {'RES 0': 13, 'RES 1': 0},
#    '床位费发生金额_SUM': {'RES 0': 88, 'RES 1': 9},
#    '床位费申报金额_SUM': {'RES 0': 81, 'RES 1': 9},
#    '医用材料发生金额_SUM': {'RES 0': 1037, 'RES 1': 30},
#    '高价材料发生金额_SUM': {'RES 0': 12, 'RES 1': 1},
#    '医用材料费自费金额_SUM': {'RES 0': 342, 'RES 1': 14},
#    '成分输血申报金额_SUM': {'RES 0': 0, 'RES 1': 1},
#    '其它发生金额_SUM': {'RES 0': 563, 'RES 1': 13},
#    '其它申报金额_SUM': {'RES 0': 1, 'RES 1': 0},
#    '一次性医用材料申报金额_SUM': {'RES 0': 1013, 'RES 1': 24},
#    '起付线标准金额_MAX': {'RES 0': 7, 'RES 1': 0},
#    '起付标准以上自负比例金额_SUM': {'RES 0': 697, 'RES 1': 33},
#    '医疗救助个人按比例负担金额_SUM': {'RES 0': 24, 'RES 1': 9},
#    '最高限额以上金额_SUM': {'RES 0': 0, 'RES 1': 0},
#    '基本统筹基金支付金额_SUM': {'RES 0': 914, 'RES 1': 32},
#    '公务员医疗补助基金支付金额_SUM': {'RES 0': 66, 'RES 1': 1},
#    '城乡救助补助金额_SUM': {'RES 0': 299, 'RES 1': 14},
#    '基本个人账户支付_SUM': {'RES 0': 1124, 'RES 1': 37},
#    '非账户支付金额_SUM': {'RES 0': 764, 'RES 1': 35},
#    '本次审批金额_SUM': {'RES 0': 860, 'RES 1': 32},
#    '补助审批金额_SUM': {'RES 0': 301, 'RES 1': 15},
#    '医疗救助医院申请_SUM': {'RES 0': 24, 'RES 1': 10},
#    '残疾军人补助_SUM': {'RES 0': 2, 'RES 1': 0},
#    '民政救助补助_SUM': {'RES 0': 299, 'RES 1': 13},
#    '城乡优抚补助_SUM': {'RES 0': 0, 'RES 1': 1},
#    '药品在总金额中的占比': {'RES 0': 1866, 'RES 1': 52},
#    '个人支付的药品占比': {'RES 0': 606, 'RES 1': 20},
#    '检查总费用在总金额占比': {'RES 0': 837, 'RES 1': 16},
#    '个人支付检查费用占比': {'RES 0': 243, 'RES 1': 13},
#    '治疗费用在总金额占比': {'RES 0': 436, 'RES 1': 34},
#    '个人支付治疗费用占比': {'RES 0': 278, 'RES 1': 7},
#    'BZ_民政救助': {'RES 0': 304, 'RES 1': 14},
#    'BZ_城乡优抚': {'RES 0': 0, 'RES 1': 1}})]

# %% [markdown]
# ### 直方图

# %%
features = data.columns[26:70]

def plot_histogram(feature):
    # 原始数据分布
    plt.figure(figsize=(15, 6))

    plt.subplot(1, 2, 1)
    data[feature].hist(bins=200, color='orange')
    plt.title(f'Original Histogram: {feature}')
    plt.xlabel('Value')
    plt.ylabel('Frequency')
    plt.grid(False)

    # 对数变换
    log_transformed = np.log1p(data[feature] + 1e-9) 


    plt.subplot(1, 2, 2)
    log_transformed.hist(bins=200, color='orange')
    plt.title(f'Log Transformed Histogram: {feature}')
    plt.xlabel('log(Value)')
    plt.ylabel('Frequency')
    plt.grid(False)

    plt.show()

# %%
interact(plot_histogram, feature=features)
# Out:
# interactive(children=(Dropdown(description='feature', options=('个人账户金额_SUM', '统筹支付金额_SUM', 'ALL_SUM', '可用账户报销金…
# <function __main__.plot_histogram(feature)>

# %% [markdown]
# ### 小提琴图

# %%
features = data.columns[26:70]

def plot_violin(feature):
    plt.figure(figsize=(10, 6))
    sns.violinplot(x=data['RES'], y=data[feature])
    plt.title(f'Violin Plot for {feature}')
    plt.xlabel('RES')
    plt.ylabel(feature)
    plt.show()


dropdown = Dropdown(options=features)
interact(plot_violin, feature=dropdown)
# Out:
# interactive(children=(Dropdown(description='feature', options=('个人账户金额_SUM', '统筹支付金额_SUM', 'ALL_SUM', '可用账户报销金…
# <function __main__.plot_violin(feature)>

# %% [markdown]
# ## 交易时间

# %%
specified_columns = ['交易时间DD_NN', '交易时间YYYY_NN', '交易时间YYYYMM_NN', '就诊的月数']
present_columns = [col for col in specified_columns if col in data.columns]

unique_counts = {col: data[col].nunique() for col in present_columns} if present_columns else {}

present_columns, unique_counts  # 种类数
# Out:
# (['交易时间DD_NN', '交易时间YYYY_NN', '交易时间YYYYMM_NN', '就诊的月数'],
#  {'交易时间DD_NN': 148, '交易时间YYYY_NN': 1, '交易时间YYYYMM_NN': 7, '就诊的月数': 7})

# %%
category_counts = {col: data[col].value_counts() for col in present_columns}

# 不同种类下个数
category_counts
# Out:
# {'交易时间DD_NN': 交易时间DD_NN
#  26     537
#  27     472
#  25     461
#  24     435
#  13     422
#        ...
#  173      1
#  153      1
#  171      1
#  159      1
#  172      1
#  Name: count, Length: 148, dtype: int64,
#  '交易时间YYYY_NN': 交易时间YYYY_NN
#  1    16000
#  Name: count, dtype: int64,
#  '交易时间YYYYMM_NN': 交易时间YYYYMM_NN
#  6    14571
#  5      720
#  4      278
#  3      182
#  2      134
#  1      112
#  7        3
#  Name: count, dtype: int64,
#  '就诊的月数': 就诊的月数
#  6    14571
#  5      720
#  4      278
#  3      182
#  2      134
#  1      112
#  7        3
#  Name: count, dtype: int64}

# %% [markdown]
# # 相关性分析

# %% [markdown]
# ## 互信息
#
# - 优点：能够捕捉变量之间的任何类型的关系，不限于线性关系，适用于连续和离散变量。
# -
# 缺点：对于大数据集计算可能较为复杂
# -
# 使用场景：特征选择和变量之间关系的复杂性评估，如在分类问题中评估特征与类别标签之间的相关性。

# %%
# Separate features and target variable
X = data.drop('RES', axis=1)
y = data['RES']

mutual_info = mutual_info_classif(X, y)

# %%
mutual_info
# Out:
# array([2.16165646e-03, 1.50446517e-02, 6.57113970e-03, 3.18081092e-02,
#        3.07622441e-02, 1.15423075e-02, 6.63667538e-03, 3.09550938e-02,
#        3.51806994e-02, 3.37312194e-02, 4.53119135e-02, 3.67446273e-02,
#        3.53860958e-02, 3.93817970e-02, 2.16615089e-02, 1.41748221e-02,
#        2.57309960e-02, 9.74025977e-03, 2.64881873e-02, 1.17652890e-02,
#        5.96520383e-03, 3.52061161e-02, 3.15575159e-02, 1.13161182e-03,
#        9.31708906e-03, 1.01972525e-04, 2.99531520e-02, 3.78294188e-02,
#        4.71916995e-02, 2.59958609e-02, 3.81452748e-02, 5.79229520e-03,
#        3.37006530e-02, 1.40987247e-02, 1.13671598e-02, 4.54219448e-03,
#        0.00000000e+00, 4.87864259e-03, 3.67180078e-03, 1.52424261e-03,
#        1.83488031e-02, 7.14318015e-05, 1.70910208e-02, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 2.92852336e-03, 4.45087545e-04,
#        6.54916602e-03, 1.44084243e-03, 2.39059695e-03, 1.85694224e-03,
#        2.87379203e-03, 1.69115975e-03, 2.05025579e-03, 1.48995350e-03,
#        3.79541672e-02, 1.78561153e-02, 2.71006514e-03, 3.54045454e-02,
#        0.00000000e+00, 1.12290359e-02, 3.35322884e-03, 3.11340425e-02,
#        4.60014271e-02, 1.23320076e-02, 1.99143683e-02, 2.47633843e-03,
#        1.17642857e-02, 0.00000000e+00, 1.49835072e-02, 4.82083307e-03,
#        1.28767626e-02, 6.65837932e-04, 0.00000000e+00, 1.20565946e-03,
#        1.20956617e-02, 1.57232508e-04, 4.63926455e-03, 7.23012085e-04,
#        0.00000000e+00])

# %%
# Create a DataFrame for the mutual information scores, including the feature names
mutual_info_df = pd.DataFrame(mutual_info, index=X.columns, columns=['Mutual Information Score'])

# Sort the scores in descending order
mutual_info_sorted = mutual_info_df.sort_values(by='Mutual Information Score', ascending=False)

# Plotting
plt.figure(figsize=(10, 20))
plt.barh(mutual_info_sorted.index, mutual_info_sorted['Mutual Information Score'], color='skyblue')
plt.xlabel('Mutual Information Score')
plt.ylabel('Features')
plt.title('Mutual Information between Features and Target')
plt.gca().invert_yaxis()  # To display the highest scores at the top
plt.show()

# Returning the sorted mutual information scores with feature names
mutual_info_sorted
# Out:
#                    Mutual Information Score
# ALL_SUM                            0.047192
# 本次审批金额_SUM                         0.046001
# 月统筹金额_MAX                          0.045312
# 月药品金额_AVG                          0.039382
# 药品费发生金额_SUM                        0.038145
# 起付标准以上自负比例金额_SUM                   0.037954
# 统筹支付金额_SUM                         0.037829
# 月统筹金额_AVG                          0.036745
# 基本统筹基金支付金额_SUM                     0.035405
# 月药品金额_MAX                          0.035386
# 顺序号_NN                             0.035206
# 月就诊次数_MAX                          0.035181
# 月就诊次数_AVG                          0.033731
# 药品费申报金额_SUM                        0.033701
# 月就诊天数_MAX                          0.031808
# 交易时间DD_NN                          0.031558
# 非账户支付金额_SUM                        0.031134
# 就诊次数_SUM                           0.030955
# 月就诊天数_AVG                          0.030762
# 个人账户金额_SUM                         0.029953
# 医院_药品_MAX                          0.026488
# 可用账户报销金额_SUM                       0.025996
# 医院_统筹金_MAX                         0.025731
# 医院_就诊天数_MAX                        0.021662
# 医疗救助医院申请_SUM                       0.019914
# 治疗费发生金额_SUM                        0.018349
# 医疗救助个人按比例负担金额_SUM                  0.017856
# 治疗费申报金额_SUM                        0.017091
# 一天去两家医院的天数                         0.015045
# 出院诊断病种名称_NN                        0.014984
# 医院_就诊天数_AVG                        0.014175
# 贵重药品发生金额_SUM                       0.014099
# 药品在总金额中的占比                         0.012877
# 补助审批金额_SUM                         0.012332
# 治疗费用在总金额占比                         0.012096
# 医院_药品_AVG                          0.011765
# 民政救助补助_SUM                         0.011764
# 月就诊医院数_MAX                         0.011542
# 中成药费发生金额_SUM                       0.011367
# 城乡救助补助金额_SUM                       0.011229
# 医院_统筹金_AVG                         0.009740
# 交易时间YYYYMM_NN                      0.009317
# 月就诊医院数_AVG                         0.006637
# 就诊的月数                              0.006571
# 医用材料发生金额_SUM                       0.006549
# 医院编码_NN                            0.005965
# 药品费自费金额_SUM                        0.005792
# 检查费自费金额_SUM                        0.004879
# 出院诊断LENTH_MAX                      0.004821
# BZ_民政救助                            0.004639
# 中草药费发生金额_SUM                       0.004542
# 检查费申报金额_SUM                        0.003672
# 基本个人账户支付_SUM                       0.003353
# 床位费发生金额_SUM                        0.002929
# 其它发生金额_SUM                         0.002874
# 最高限额以上金额_SUM                       0.002710
# 残疾军人补助_SUM                         0.002476
# 医用材料费自费金额_SUM                      0.002391
# 个人编码                               0.002162
# 一次性医用材料申报金额_SUM                    0.002050
# 成分输血申报金额_SUM                       0.001857
# 其它申报金额_SUM                         0.001691
# 贵重检查费金额_SUM                        0.001524
# 起付线标准金额_MAX                        0.001490
# 高价材料发生金额_SUM                       0.001441
# 个人支付检查费用占比                         0.001206
# 交易时间YYYY_NN                        0.001132
# BZ_城乡优抚                            0.000723
# 个人支付的药品占比                          0.000666
# 床位费申报金额_SUM                        0.000445
# 个人支付治疗费用占比                         0.000157
# 住院天数_SUM                           0.000102
# 治疗费自费金额_SUM                        0.000071
# 检查费发生金额_SUM                        0.000000
# 检查总费用在总金额占比                        0.000000
# 公务员医疗补助基金支付金额_SUM                  0.000000
# 城乡优抚补助_SUM                         0.000000
# 手术费发生金额_SUM                        0.000000
# 手术费自费金额_SUM                        0.000000
# 手术费申报金额_SUM                        0.000000
# 是否挂号                               0.000000

# %% [markdown]
# ## 斯皮尔曼等级相关系数
#
# - 优点：不要求数据正态分布，适用于序数和非线性关系的分析。
#
# - 缺点：只能检测单调关系，可能不如皮尔逊相关系数敏感。
# 敏感。

# %%
# 计算斯皮尔曼等级相关系数
spearman_corr = data.corr(method='spearman')

# 绘制热力图以可视化相关性
plt.figure(figsize=(20, 15))
sns.heatmap(spearman_corr, cmap='coolwarm', annot=False, linewidths=.5)
plt.title('Spearman Rank Correlation Heatmap')
plt.show()

# %%
# 返回相关系数数值
spearman_corr.head()  # 显示部分相关性数值，以便查看结果格式
# Out:
#             一天去两家医院的天数     就诊的月数  月就诊天数_MAX  月就诊天数_AVG  月就诊医院数_MAX  \
# 一天去两家医院的天数    1.000000  0.084153   0.344112   0.336584    0.481109
# 就诊的月数         0.084153  1.000000   0.177892   0.201465    0.116925
# 月就诊天数_MAX     0.344112  0.177892   1.000000   0.950718    0.392132
# 月就诊天数_AVG     0.336584  0.201465   0.950718   1.000000    0.369093
# 月就诊医院数_MAX    0.481109  0.116925   0.392132   0.369093    1.000000
#
#             月就诊医院数_AVG  就诊次数_SUM  月就诊次数_MAX  月就诊次数_AVG  月统筹金额_MAX  月统筹金额_AVG  \
# 一天去两家医院的天数    0.546596  0.452818   0.454358   0.454435   0.298474   0.329199
# 就诊的月数         0.129903  0.320169   0.177925   0.201751   0.094291   0.119637
# 月就诊天数_MAX     0.417992  0.924909   0.979539   0.941060   0.427133   0.472339
# 月就诊天数_AVG     0.420879  0.968574   0.934883   0.985060   0.381817   0.489678
# 月就诊医院数_MAX    0.920252  0.422834   0.452891   0.427893   0.234116   0.226540
#
#             月药品金额_MAX  月药品金额_AVG  医院_就诊天数_MAX  医院_就诊天数_AVG  医院_统筹金_MAX  \
# 一天去两家医院的天数   0.325917   0.352338     0.214669     0.113717    0.035303
# 就诊的月数        0.128134   0.157845     0.309420     0.293671    0.234535
# 月就诊天数_MAX    0.364176   0.401240     0.801688     0.609307    0.257546
# 月就诊天数_AVG    0.323833   0.422232     0.857479     0.672939    0.282297
# 月就诊医院数_MAX   0.287097   0.278701     0.032238    -0.312647   -0.215576
#
#             医院_统筹金_AVG  医院_药品_MAX  医院_药品_AVG   医院编码_NN    顺序号_NN  交易时间DD_NN  \
# 一天去两家医院的天数   -0.069848   0.053981  -0.050682  0.456578  0.424760   0.335995
# 就诊的月数         0.204301   0.271785   0.236959  0.093382  0.321539   0.323802
# 月就诊天数_MAX     0.111711   0.200943   0.074229  0.364607  0.840245   0.932679
# 月就诊天数_AVG     0.147690   0.228525   0.114023  0.335408  0.880134   0.981607
# 月就诊医院数_MAX   -0.551626  -0.169559  -0.523256  0.962550  0.358824   0.364752
#
#             交易时间YYYY_NN  交易时间YYYYMM_NN  住院天数_SUM  个人账户金额_SUM  统筹支付金额_SUM  \
# 一天去两家医院的天数          NaN       0.084153       NaN    0.238318    0.332507
# 就诊的月数               NaN       1.000000       NaN    0.179938    0.273243
# 月就诊天数_MAX           NaN       0.177892       NaN    0.351783    0.478237
# 月就诊天数_AVG           NaN       0.201465       NaN    0.354353    0.495175
# 月就诊医院数_MAX          NaN       0.116925       NaN    0.157578    0.233313
#
#              ALL_SUM  可用账户报销金额_SUM  药品费发生金额_SUM  药品费自费金额_SUM  药品费申报金额_SUM  \
# 一天去两家医院的天数  0.329401      0.244624     0.354862     0.136918     0.356745
# 就诊的月数       0.260781      0.183590     0.302779     0.138782     0.305560
# 月就诊天数_MAX   0.474832      0.347778     0.406210     0.232559     0.409989
# 月就诊天数_AVG   0.489434      0.352393     0.426941     0.241956     0.431615
# 月就诊医院数_MAX  0.231280      0.168050     0.282275     0.146938     0.285448
#
#             贵重药品发生金额_SUM  中成药费发生金额_SUM  中草药费发生金额_SUM  检查费发生金额_SUM  \
# 一天去两家医院的天数      0.187712      0.318112      0.043018    -0.038286
# 就诊的月数           0.083051      0.236887      0.066792     0.051861
# 月就诊天数_MAX       0.167049      0.318173      0.052332     0.022308
# 月就诊天数_AVG       0.165401      0.330115      0.025856     0.020511
# 月就诊医院数_MAX      0.175528      0.304224      0.116383    -0.033656
#
#             检查费自费金额_SUM  检查费申报金额_SUM  贵重检查费金额_SUM  治疗费发生金额_SUM  治疗费自费金额_SUM  \
# 一天去两家医院的天数    -0.042782    -0.037394    -0.033369     0.270967     0.005360
# 就诊的月数         -0.020664     0.053745    -0.068364     0.194678     0.022943
# 月就诊天数_MAX     -0.031389     0.024164    -0.090172     0.495190    -0.013174
# 月就诊天数_AVG     -0.044012     0.022724    -0.123928     0.499372    -0.018061
# 月就诊医院数_MAX    -0.020718    -0.033534     0.019018     0.277664     0.073364
#
#             治疗费申报金额_SUM  手术费发生金额_SUM  手术费自费金额_SUM  手术费申报金额_SUM  床位费发生金额_SUM  \
# 一天去两家医院的天数     0.274843    -0.012492     0.004031    -0.012727     0.095287
# 就诊的月数          0.197629    -0.025562    -0.015509    -0.019177     0.020758
# 月就诊天数_MAX      0.502637    -0.020189     0.000975    -0.018666     0.111152
# 月就诊天数_AVG      0.507691    -0.030157    -0.001390    -0.028826     0.081601
# 月就诊医院数_MAX     0.280671    -0.014674     0.013058    -0.016224     0.117398
#
#             床位费申报金额_SUM  医用材料发生金额_SUM  高价材料发生金额_SUM  医用材料费自费金额_SUM  \
# 一天去两家医院的天数     0.095050      0.019827     -0.027001      -0.020861
# 就诊的月数          0.022562      0.089367     -0.033485       0.007034
# 月就诊天数_MAX      0.114601      0.089449      0.027978      -0.102830
# 月就诊天数_AVG      0.085587      0.112761      0.027132      -0.125141
# 月就诊医院数_MAX     0.118109      0.043508     -0.050589       0.068780
#
#             成分输血申报金额_SUM  其它发生金额_SUM  其它申报金额_SUM  一次性医用材料申报金额_SUM  \
# 一天去两家医院的天数     -0.008043    0.115877    0.006306         0.025581
# 就诊的月数          -0.024663    0.049141   -0.015779         0.090440
# 月就诊天数_MAX      -0.003777    0.177145    0.027079         0.082635
# 月就诊天数_AVG      -0.011782    0.168891    0.027177         0.108850
# 月就诊医院数_MAX     -0.020620    0.182467   -0.008108         0.060617
#
#             起付线标准金额_MAX  起付标准以上自负比例金额_SUM  医疗救助个人按比例负担金额_SUM  最高限额以上金额_SUM  \
# 一天去两家医院的天数     0.011692          0.314202           0.071338     -0.003891
# 就诊的月数         -0.022377          0.221109          -0.016517     -0.023997
# 月就诊天数_MAX      0.029762          0.446819           0.114019     -0.003342
# 月就诊天数_AVG      0.030264          0.453366           0.107941     -0.006075
# 月就诊医院数_MAX     0.008024          0.213363           0.015255     -0.010419
#
#             基本统筹基金支付金额_SUM  公务员医疗补助基金支付金额_SUM  城乡救助补助金额_SUM  基本个人账户支付_SUM  \
# 一天去两家医院的天数        0.328688          -0.025058      0.121819     -0.030459
# 就诊的月数             0.276018           0.001279      0.037342      0.106412
# 月就诊天数_MAX         0.476565          -0.021079      0.136888     -0.003711
# 月就诊天数_AVG         0.494934          -0.020314      0.135253      0.000232
# 月就诊医院数_MAX        0.232379          -0.033682      0.084994     -0.034068
#
#             非账户支付金额_SUM  本次审批金额_SUM  补助审批金额_SUM  医疗救助医院申请_SUM  残疾军人补助_SUM  \
# 一天去两家医院的天数     0.242809    0.331778    0.121142      0.070985   -0.009533
# 就诊的月数          0.175034    0.264522    0.037953     -0.016341    0.006032
# 月就诊天数_MAX      0.356965    0.480889    0.136465      0.113427   -0.004498
# 月就诊天数_AVG      0.359691    0.496297    0.134698      0.107415   -0.007437
# 月就诊医院数_MAX     0.168244    0.232756    0.084176      0.015225   -0.012851
#
#             民政救助补助_SUM  城乡优抚补助_SUM  出院诊断病种名称_NN  出院诊断LENTH_MAX  药品在总金额中的占比  \
# 一天去两家医院的天数    0.121846    0.000447     0.381300       0.124663    0.058952
# 就诊的月数         0.036907    0.007389     0.207463       0.189051    0.081117
# 月就诊天数_MAX     0.136649    0.005054     0.581990       0.155902   -0.081980
# 月就诊天数_AVG     0.134917    0.006321     0.602534       0.188335   -0.069435
# 月就诊医院数_MAX    0.085600   -0.007113     0.429638       0.137419    0.067093
#
#             个人支付的药品占比  检查总费用在总金额占比  个人支付检查费用占比  治疗费用在总金额占比  个人支付治疗费用占比  \
# 一天去两家医院的天数   0.082714    -0.117017   -0.042989    0.114579   -0.000923
# 就诊的月数        0.103583    -0.025099   -0.021112    0.007580    0.020614
# 月就诊天数_MAX    0.178493    -0.108782   -0.029798    0.288283   -0.022915
# 月就诊天数_AVG    0.186706    -0.115597   -0.042165    0.284349   -0.027415
# 月就诊医院数_MAX   0.109857    -0.074426   -0.021423    0.147046    0.067727
#
#              BZ_民政救助   BZ_城乡优抚      是否挂号       RES  个人账户使用异常指数
# 一天去两家医院的天数  0.111352  0.000442 -0.114039  0.128686   -0.020952
# 就诊的月数       0.033096  0.007389  0.006755 -0.069563   -0.041896
# 月就诊天数_MAX   0.120994  0.005052 -0.164446  0.155719   -0.067656
# 月就诊天数_AVG   0.119121  0.006319 -0.168648  0.128285   -0.058744
# 月就诊医院数_MAX  0.081517 -0.007113 -0.149032  0.088181   -0.091786

# %% [markdown]
# # 关联规则
#
#
#
#
# 1. **min_support (`最小支持度`)**：
#    - `min_support` 参数定义了一个项集（Itemset）在数据集中出现的最小频率。
#    - 在关联规则挖掘中，支持度是一个重要的度量，它表示一个项集在所有事务中出现的频率。例如，如果有100个事务，其中有30个事务包含某个特定项集，那么这个项集的支持度就是30/100 = 0.3。
#    - 设置`min_support` 是为了筛选出足够频繁出现的项集，这些项集被认为是“频繁项集”，并用于进一步挖掘关联规则。
#    - 选择合适的`min_support` 值很重要。太高的值可能导致错过有意义的规则，而太低的值可能会生成大量无关紧要的规则。
#
# 2. **use_colnames (`使用列名`)**：
#    - 默认情况下，Apriori算法会使用数字索引来表示数据集中的项（特征）。当`use_colnames` 设置为`True`时，算法会使用数据帧的列名来代替数字索引。
#    - 这使得结果更容易理解，因为您会看到实际的特征名称，而不是它们的数字索引。
#    - 例如，如果您有一个特征叫做`高频就诊`，在生成的频繁项集和关联规则中，这个特征会直接显示为`高频就诊`，而更好地解释和理解分析结果。

# %%
import pandas as pd
from mlxtend.frequent_patterns import apriori, association_rules
from mlxtend.preprocessing import TransactionEncoder


# 假设我们选择了一些特征进行分析，您需要根据您的数据集进行调整
selected_features = ['一天去两家医院的天数', '就诊次数_SUM', '顺序号_NN', ]

# 数据预处理：将选定特征转换为事务格式
# 这里需要您根据具体数据集结构来编写适当的转换代码

# 定义二元化的阈值
threshold_for_hospital_visits = 2  # 假设的阈值
threshold_for_visits = data['就诊次数_SUM'].median()  # 使用中位数作为阈值

# 数据二元化转换
data['频繁双医院访问'] = data['一天去两家医院的天数'].apply(lambda x: 1 if x > threshold_for_hospital_visits else 0)
data['高频就诊'] = data['就诊次数_SUM'].apply(lambda x: 1 if x > threshold_for_visits else 0)
# 对于顺序号_NN，您需要根据实际情况来决定如何二元化
# data['顺序号_NN_二元化'] = data['顺序号_NN'].apply(lambda x: ...)

# 选择二元化后的特征进行分析
selected_features = ['频繁双医院访问', '高频就诊', ]  # 这里的...代表其他可能的二元化特征
transactions = data[selected_features].values.tolist()

# 示例转换代码（需要根据您的数据结构调整）
# transactions = data[selected_features].values.tolist()

# 转换数据格式
te = TransactionEncoder()
te_ary = te.fit(transactions).transform(transactions)
df = pd.DataFrame(te_ary, columns=te.columns_)

# 应用Apriori算法
frequent_itemsets = apriori(df, min_support=0.3, use_colnames=True)

# 挖掘关联规则
rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.8)

# 显示规则
print(rules[['antecedents', 'consequents', 'support', 'confidence', 'lift']])
# Out:
# Empty DataFrame
# Columns: [antecedents, consequents, support, confidence, lift]
# Index: []

# %%
# !pip install mlxtend

# %% [markdown]
# # 数据分箱

# %%
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# ## 聚类分箱

# %%
# 选取并标准化特征
features = data[['顺序号_NN', '医院编码_NN']].values
scaler = StandardScaler()
features_scaled = scaler.fit_transform(features)

# 应用k-means聚类
kmeans = KMeans(n_clusters=4, random_state=42)
data['cluster'] = kmeans.fit_predict(features_scaled)

# 可视化聚类效果
plt.figure(figsize=(12, 6))

# 散点图
plt.subplot(1, 2, 1)
sns.scatterplot(x='顺序号_NN', y='医院编码_NN', hue='cluster', data=data, palette='viridis')
plt.title('Scatter Plot of Clusters')
plt.xlabel('顺序号_NN')
plt.ylabel('医院编码_NN')

# 计数图
plt.subplot(1, 2, 2)
sns.countplot(x='cluster', data=data, palette='viridis')
plt.title('Cluster Counts')
plt.xlabel('Cluster')
plt.ylabel('Count')

plt.tight_layout()
plt.show()

# 计算每个聚类中“RES”的分布
cluster_counts = data.groupby(['cluster', 'RES']).size().unstack(fill_value=0)
cluster_counts
# Out:
# RES         0    1
# cluster
# 0         558  264
# 1        5984  153
# 2        4097  127
# 3        4568  249
